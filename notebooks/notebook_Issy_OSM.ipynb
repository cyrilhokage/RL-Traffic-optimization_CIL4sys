# %% [markdown]
# # Networks from OpenStreetMap
#
# - import networks from OpenStreetMap.
# - integrate it and run it in Flow.

# %%
# the TestEnv environment is used to simply simulate the network
from flow.envs import TestEnv

# the Experiment class is used for running simulations
from flow.core.experiment import Experiment

# all other imports are standard
from flow.core.params import VehicleParams
from flow.core.params import NetParams, SumoCarFollowingParams
from flow.core.params import InitialConfig
from flow.core.params import EnvParams
from flow.core.params import SumoParams
from flow.controllers import RLController, IDMController

from flow.networks import Network

# %% [markdown]
# ## 1. Ajouter un flux de voiture

# %%
from flow.core.params import InFlows

inflow = InFlows()

inflow.add(veh_type      = "human",
           edge          = "4794817",
           probability   = 0.3, 
           depart_speed  = 7,
           depart_lane   = "random")

inflow.add(veh_type      = "human",
           edge          = "4783299#0",
           probability   = 0.2,
           depart_speed  = 7,
           depart_lane   = "random")

inflow.add(veh_type       = "human",
           acceleration_controller = (IDMController, {}),
           edge           = "-100822066",
           probability    = 0.25,
           depart_speed   = 7,
           depart_lane    = "random")

inflow.add(veh_type       = "rl",
           acceleration_controller = (RLController, {}),
           edge           = "-100822066",
           probability    = 0.05,
           depart_speed   = 7,
           depart_lane    = "random",
           color          = "red")


inflow.add(veh_type       = "human",
           edge          = "155558218",
           probability   = 0.2,
           depart_speed  = 7,
           depart_lane   = "random")

# %% [markdown]
# ## 2. Créer des itinéraires

# %%
# Specifie les noms des edges du network dont les vehicules peuvent être originaire
EDGES_DISTRIBUTION = [
    "-100822066",
    "4794817",
    "4783299#0",
    "155558218",
]

# %%
# créer une nouvelle classe Network pour spécifier les itinéraires possibles
class IssyOSMNetwork(Network):

    def specify_routes(self, net_params):
        return {
            "-100822066": [ #N
                "-100822066",
                "-352962858#1",
                "-352962858#0",
                "-4786940#1",
                 "-4786940#0",
            ],
            
            "4794817" : [ #Loop
                "4794817",
                "4786972#0",
                "4786972#1",
                "4786972#2",
                "4786965#1",
                "4786965#2",
                "4786965#3",
                "4795729",
                "-352962858#1",
                "4795742#0",
                "4795742#1",
                "4786965#3",
                "4786965#4",
                "4786965#5",
            ],
            
            "4783299#0": [    #E
                "4783299#0",
                "4783299#1",
                "4783299#2",
                "4783299#3",
                "4783299#4",
                "4783299#5",
                "4783299#6",
                "4786940#0",
                "4786940#1",
                "352962858#0",
                "352962858#1",
                "100822066",
            ],
            
            "155558218": [
                "155558218",
                "4786940#1",
                "352962858#0",
                "352962858#1",
                "100822066",
            ],     
        }

# %% [markdown]
# # Personnaliser un Environnement pour le RL
#
# More accessor objects and methods can be found within the Flow documentation at: http://berkeleyflow.readthedocs.io/en/latest/

# %%
# import the base environment class
from flow.envs import Env
from gym.spaces.box import Box
from gym.spaces import Tuple
import numpy as np

# %% [markdown]
# ## definition de la classe environnement

# %%
class myEnv(Env):
    pass

# %% [markdown]
# ## fonction action_space
# 2 actions possibles pour chaque véhicule RL : +1 acceleration ou -1 acceleration

# %%
class myEnv(myEnv): # update my environment class

    @property
    def action_space(self):
        num_actions = self.initial_vehicles.num_rl_vehicles
        accel_ub = self.env_params.additional_params["max_accel"]
        accel_lb = - abs(self.env_params.additional_params["max_decel"])

        return Box(low=accel_lb,
                   high=accel_ub,
                   shape=(num_actions,))

# %% [markdown]
# ## observation_space
# 2 valeurs observé pour chaque véhicule: sa **position** et sa **vitesse**. En conséquence, nous avons besoin d'un espace d'observation qui est *deux fois plus grand que le nombre de véhicules* dans le network.

# %%
class myEnv(myEnv):  # update my environment class

    @property
    def observation_space(self):
        return Box(
            low=0,
            high=float("inf"),
            shape=(2*self.initial_vehicles.num_vehicles,))

# %% [markdown]
# ## apply_rl_actions
# `apply_rl_actions` : transforme les commandes de l'agent RL en actions réelles du simulateur.
#
# Pour notre exemple, l'agent RL peut spécifier que les accélérations des véhicules RL avec la fonction **apply_acceleration**

# %%
class myEnv(myEnv):  # update my environment class

    def _apply_rl_actions(self, rl_actions):
        # the names of all autonomous (RL) vehicles in the network
        rl_ids = self.k.vehicle.get_rl_ids()

        # use the base environment method to convert actions into accelerations for the rl vehicles
        self.k.vehicle.apply_acceleration(rl_ids, rl_actions)

# %% [markdown]
# ## get_state
#
# `get_state` : extrait des features de l'environnement et fournit ensuite des entrées à la stratégie fournie par l'agent RL.

# %%
class myEnv(myEnv):  # update my environment class

    def get_state(self, **kwargs):
        # the get_ids() method is used to get the names of all vehicles in the network
        ids = self.k.vehicle.get_ids()

        # we use the get_absolute_position method to get the positions of all vehicles
        pos = [self.k.vehicle.get_x_by_id(veh_id) for veh_id in ids]

        # we use the get_speed method to get the velocities of all vehicles
        vel = [self.k.vehicle.get_speed(veh_id) for veh_id in ids]

        # the speeds and positions are concatenated to produce the state
        return np.concatenate((pos, vel))

# %% [markdown]
# ## compute_reward
#
# `compute_reward` : renvoie la récompense associée à un état donné.
#
# Ici, la fonction de récompense est la **vitesse moyenne de tous les véhicules actuellement sur le réseau**.

# %%
class myEnv(myEnv):  # update my environment class

    def compute_reward(self, rl_actions, **kwargs):
        # the get_ids() method is used to get the names of all vehicles in the network
        ids = self.k.vehicle.get_ids()

        # we next get a list of the speeds of all vehicles in the network
        speeds = self.k.vehicle.get_speed(ids)

        # finally, we return the average of all these speeds as the reward
        return np.mean(speeds)

# %% [markdown]
# # Testing

# %%
HORIZON = 1000

# %%
from flow.core.experiment import Experiment
from flow.core.params import SumoParams, EnvParams, InitialConfig, NetParams
from flow.core.params import VehicleParams
from flow.networks.ring import RingNetwork, ADDITIONAL_NET_PARAMS

ADDITIONAL_ENV_PARAMS = {"max_accel": 1, "max_decel": 1}

# %%
'''
# SUMO PARAM
sumo_params = SumoParams(sim_step=0.1, render=True)

# create VEHICLE
vehicles = VehicleParams()
vehicles.add(veh_id="human",
             acceleration_controller=(IDMController, {}),
             num_vehicles=22)

# ENVIRONMENT PARAM
env_params = EnvParams(additional_params=ADDITIONAL_ENV_PARAMS, horizon=HORIZON)

# NETWORK PARAM
additional_net_params = ADDITIONAL_NET_PARAMS.copy()
net_params = NetParams(additional_params=additional_net_params, inflows=inflow, osm_path='issy.osm')

# NETWORK
network = IssyOSMNetwork

# INITIAL CONFIG
initial_config = InitialConfig(edges_distribution=EDGES_DISTRIBUTION) #spacing="random",

# dictionnaire FLOW_PARAM
flow_params = dict( exp_tag  = 'ISSY_RL_test',
                    env_name = myEnv,  # using my new environment for the simulation
                    network  = network,
                    simulator= 'traci',
                    sim      = sumo_params,
                    env      = env_params,
                    net      = net_params,
                    veh      = vehicles,
                    initial  = initial_config)

# create EXPERIMENT with class created
exp = Experiment(flow_params)

# RUN SIMULATION SUMO
_ = exp.run(1)
'''
# Out:
# '\n# SUMO PARAM\nsumo_params = SumoParams(sim_step=0.1, render=True)\n\n# create VEHICLE\nvehicles = VehicleParams()\nvehicles.add(veh_id="human",\n             acceleration_controller=(IDMController, {}),\n             num_vehicles=22)\n\n# ENVIRONMENT PARAM\nenv_params = EnvParams(additional_params=ADDITIONAL_ENV_PARAMS, horizon=HORIZON)\n\n# NETWORK PARAM\nadditional_net_params = ADDITIONAL_NET_PARAMS.copy()\nnet_params = NetParams(additional_params=additional_net_params, inflows=inflow, osm_path=\'issy.osm\')\n\n# NETWORK\nnetwork = IssyOSMNetwork\n\n# INITIAL CONFIG\ninitial_config = InitialConfig(edges_distribution=EDGES_DISTRIBUTION) #spacing="random",\n\n# dictionnaire FLOW_PARAM\nflow_params = dict( exp_tag  = \'ISSY_RL_test\',\n                    env_name = myEnv,  # using my new environment for the simulation\n                    network  = network,\n                    simulator= \'traci\',\n                    sim      = sumo_params,\n                    env      = env_params,\n                    net      = net_params,\n                    veh      = vehicles,\n                    initial  = initial_config)\n\n# create EXPERIMENT with class created\nexp = Experiment(flow_params)\n\n# RUN SIMULATION SUMO\n_ = exp.run(1)\n'

# %% [markdown]
# # Training
#
# Pour qu'un environnement puisse être entrainé, l'environnement doit être accessible via l'importation à partir de flow.envs.
#
#
# <font color='red'>
# Copier l'environnement créé dans un fichier .py et on importe l'environnement dans `flow.envs.__init__.py`.
# Mettre le chemin absolu du fichier .osm .
# </font>

# %%
# NOTE: only runs if the above procedure have been performed
from flow.envs import myEnv as myEnv
from flow.envs import AccelEnv as myEnv

# %%
import json
import ray
from ray.rllib.agents.registry import get_agent_class
from ray.tune import run_experiments
from ray.tune.registry import register_env

from flow.networks.ring import ADDITIONAL_NET_PARAMS
from flow.utils.registry import make_create_env
from flow.utils.rllib import FlowParamsEncoder
from flow.core.params import VehicleParams, SumoCarFollowingParams


# number of rollouts per training iteration
N_ROLLOUTS = 10
# number of parallel workers
N_CPUS = 2

# SUMO PARAM
sumo_params = SumoParams(sim_step=0.1, render=False, restart_instance=True)

# ENVIRONMENT PARAM
ADDITIONAL_ENV_PARAMS = {"target_velocity": 20,"sort_vehicles": False,"max_accel": 1,"max_decel": 1}
env_params = EnvParams(additional_params=ADDITIONAL_ENV_PARAMS, horizon=HORIZON)

# NETWORK PARAM
additional_net_params = ADDITIONAL_NET_PARAMS.copy()
path_file  = '/home/julien/projet_CIL4SYS/issy.osm'
net_params = NetParams(additional_params=additional_net_params, inflows=inflow, osm_path=path_file)

# NETWORK
network = IssyOSMNetwork

# INITIAL CONFIG
initial_config = InitialConfig(edges_distribution=EDGES_DISTRIBUTION)

vehicles = VehicleParams()
vehicles.add(veh_id="human", acceleration_controller=(IDMController, {}), num_vehicles=5)

flow_params = dict( exp_tag   = "ISSY_RL_train", 
                    env_name  = myEnv,  
                    network   = IssyOSMNetwork,
                    simulator = 'traci', # simulator that is used by the experiment
                    sim       = sumo_params,
                    env       = env_params,
                    net       = net_params,
                    veh       = vehicles,
                    initial   = initial_config)

def setup_exps():
    """Return the relevant components of an RLlib experiment.

    Returns
    -------
    str
        name of the training algorithm
    str
        name of the gym environment to be trained
    dict
        training configuration parameters
    """
    alg_run   = "PPO"
    agent_cls = get_agent_class(alg_run)
    config    = agent_cls._default_config.copy()
    config["num_workers"]      = N_CPUS
    config["train_batch_size"] = HORIZON * N_ROLLOUTS
    config["gamma"]            = 0.999  # discount rate
    config["use_gae"]          = True
    config["lambda"]           = 0.97
    config["kl_target"]        = 0.02
    config["num_sgd_iter"]     = 10
    config['clip_actions']     = False  # FIXME(ev) temporary ray bug
    config["horizon"]          = HORIZON
    config["model"].update({"fcnet_hiddens": [3, 3]})
    
    # save the flow params for replay
    flow_json = json.dumps( flow_params, cls=FlowParamsEncoder, sort_keys=True, indent=4)
    config['env_config']['flow_params'] = flow_json
    config['env_config']['run'] = alg_run

    create_env, gym_name = make_create_env(params=flow_params, version=0)

    # Register as rllib env
    register_env(gym_name, create_env)
    
    return alg_run, gym_name, config


alg_run, gym_name, config = setup_exps()

ray.init(num_cpus=N_CPUS + 1)

trials = run_experiments({
    flow_params["exp_tag"]: {
        "run": alg_run,
        "env": gym_name,
        "config": {**config},
        "checkpoint_freq": 500,
        "checkpoint_at_end": True,
        "max_failures": 999,
        "stop": {"training_iteration": 5},
    }
})
# Out:
# 2020-03-23 16:13:04,172	INFO node.py:498 -- Process STDOUT and STDERR is being redirected to /tmp/ray/session_2020-03-23_16-13-04_172195_7832/logs.
# 2020-03-23 16:13:04,309	INFO services.py:409 -- Waiting for redis server at 127.0.0.1:18277 to respond...
# 2020-03-23 16:13:04,502	INFO services.py:409 -- Waiting for redis server at 127.0.0.1:19819 to respond...
# 2020-03-23 16:13:04,512	INFO services.py:809 -- Starting Redis shard with 2.09 GB max memory.
# 2020-03-23 16:13:04,601	INFO node.py:512 -- Process STDOUT and STDERR is being redirected to /tmp/ray/session_2020-03-23_16-13-04_172195_7832/logs.
# 2020-03-23 16:13:04,605	INFO services.py:1475 -- Starting the Plasma object store with 3.14 GB memory using /dev/shm.
# 2020-03-23 16:13:04,974	INFO trial_runner.py:176 -- Starting a new experiment.
# 2020-03-23 16:13:05,122	WARNING signature.py:108 -- The function with_updates has a **kwargs argument, which is currently not supported.
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 0/3 CPUs, 0/0 GPUs
# Memory usage on this node: 2.9/10.5 GB
# 2020-03-23 16:13:05,198	ERROR log_sync.py:34 -- Log sync requires cluster to be setup with `ray up`.
# 2020-03-23 16:13:05,649	WARNING util.py:145 -- The `start_trial` operation took 0.588240385055542 seconds to complete, which may be a performance bottleneck.
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 3/3 CPUs, 0/0 GPUs
# Memory usage on this node: 2.9/10.5 GB
# Result logdir: /home/julien/ray_results/ISSY_RL_train
# Number of trials: 1 ({'RUNNING': 1})
# RUNNING trials:
#  - PPO_AccelEnv-v0_0:	RUNNING
#
# (pid=7870) 2020-03-23 16:13:14,396	WARNING ppo.py:143 -- FYI: By default, the value function will not share layers with the policy model ('vf_share_layers': False).
# (pid=7870) Warning: Discarding unknown compound 'cycleway.opposite' in type 'cycleway.opposite|highway.residential' (first occurence for edge '4786965#0').
# (pid=7870) Warning: Discarding unknown compound 'cycleway.opposite_track' in type 'cycleway.opposite_track|highway.residential' (first occurence for edge '4786972#0').
# (pid=7870) Warning: Discarding unknown compound 'cycleway.opposite' in type 'cycleway.opposite|highway.living_street' (first occurence for edge '4795758').
# (pid=7870) Warning: Discarding unknown compound 'cycleway.lane' in type 'cycleway.lane|highway.secondary' (first occurence for edge '100822066').
# (pid=7870) Warning: Removed a road without junctions: -21549451
# (pid=7870) Warning: Removed a road without junctions: 21549451
# (pid=7870) Warning: The traffic light '30624291' does not control any links; it will not be build.
# (pid=7870) Warning: Could not build program '0' for traffic light '30624291'
# (pid=7870) Warning: Minor green from edge '-352962858#0' to edge '4786972#0' exceeds 19.44m/s. Maybe a left-turn lane is missing.
# (pid=7870) Warning: Minor green from edge '352962858#0' to edge '4794820' exceeds 19.44m/s. Maybe a left-turn lane is missing.
# (pid=7870) Warning: Minor green from edge '-352962858#1' to edge '4795742#0' exceeds 19.44m/s. Maybe a left-turn lane is missing.
# (pid=7870) Success.
# (pid=7870) 2020-03-23 16:13:16,230	INFO rollout_worker.py:319 -- Creating policy evaluation worker 0 on CPU (please ignore any CUDA init errors)
# (pid=7870) 2020-03-23 16:13:16.232904: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2
# (pid=7870) 2020-03-23 16:13:16,827	INFO dynamic_tf_policy.py:324 -- Initializing loss function with dummy input:
# (pid=7870)
# (pid=7870) { 'action_prob': <tf.Tensor 'default_policy/action_prob:0' shape=(?,) dtype=float32>,
# (pid=7870)   'actions': <tf.Tensor 'default_policy/actions:0' shape=(?, 0) dtype=float32>,
# (pid=7870)   'advantages': <tf.Tensor 'default_policy/advantages:0' shape=(?,) dtype=float32>,
# (pid=7870)   'behaviour_logits': <tf.Tensor 'default_policy/behaviour_logits:0' shape=(?, 0) dtype=float32>,
# (pid=7870)   'dones': <tf.Tensor 'default_policy/dones:0' shape=(?,) dtype=bool>,
# (pid=7870)   'new_obs': <tf.Tensor 'default_policy/new_obs:0' shape=(?, 10) dtype=float32>,
# (pid=7870)   'obs': <tf.Tensor 'default_policy/observation:0' shape=(?, 10) dtype=float32>,
# (pid=7870)   'prev_actions': <tf.Tensor 'default_policy/action:0' shape=(?, 0) dtype=float32>,
# (pid=7870)   'prev_rewards': <tf.Tensor 'default_policy/prev_reward:0' shape=(?,) dtype=float32>,
# (pid=7870)   'rewards': <tf.Tensor 'default_policy/rewards:0' shape=(?,) dtype=float32>,
# (pid=7870)   'value_targets': <tf.Tensor 'default_policy/value_targets:0' shape=(?,) dtype=float32>,
# (pid=7870)   'vf_preds': <tf.Tensor 'default_policy/vf_preds:0' shape=(?,) dtype=float32>}
# (pid=7870)
# (pid=7870) /home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py:100: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
# (pid=7870)   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# (pid=7870) 2020-03-23 16:13:20,313	INFO rollout_worker.py:742 -- Built policy map: {'default_policy': <ray.rllib.policy.tf_policy_template.PPOTFPolicy object at 0x7f8fb05070f0>}
# (pid=7870) 2020-03-23 16:13:20,313	INFO rollout_worker.py:743 -- Built preprocessor map: {'default_policy': <ray.rllib.models.preprocessors.NoPreprocessor object at 0x7f8fb0fa5d68>}
# (pid=7870) 2020-03-23 16:13:20,314	INFO rollout_worker.py:356 -- Built filter map: {'default_policy': <ray.rllib.utils.filter.NoFilter object at 0x7f8fb0fa5c18>}
# (pid=7870) 2020-03-23 16:13:20,457	INFO multi_gpu_optimizer.py:93 -- LocalMultiGPUOptimizer devices ['/cpu:0']
# (pid=7869) Warning: Discarding unknown compound 'cycleway.opposite' in type 'cycleway.opposite|highway.residential' (first occurence for edge '4786965#0').
# (pid=7869) Warning: Discarding unknown compound 'cycleway.opposite_track' in type 'cycleway.opposite_track|highway.residential' (first occurence for edge '4786972#0').
# (pid=7869) Warning: Discarding unknown compound 'cycleway.opposite' in type 'cycleway.opposite|highway.living_street' (first occurence for edge '4795758').
# (pid=7869) Warning: Discarding unknown compound 'cycleway.lane' in type 'cycleway.lane|highway.secondary' (first occurence for edge '100822066').
# (pid=7869) Warning: Removed a road without junctions: -21549451
# (pid=7869) Warning: Removed a road without junctions: 21549451
# (pid=7869) Warning: The traffic light '30624291' does not control any links; it will not be build.
# (pid=7869) Warning: Could not build program '0' for traffic light '30624291'
# (pid=7869) Warning: Minor green from edge '-352962858#0' to edge '4786972#0' exceeds 19.44m/s. Maybe a left-turn lane is missing.
# (pid=7869) Warning: Minor green from edge '352962858#0' to edge '4794820' exceeds 19.44m/s. Maybe a left-turn lane is missing.
# (pid=7869) Warning: Minor green from edge '-352962858#1' to edge '4795742#0' exceeds 19.44m/s. Maybe a left-turn lane is missing.
# (pid=7869) Success.
# (pid=7934) Warning: Discarding unknown compound 'cycleway.opposite' in type 'cycleway.opposite|highway.residential' (first occurence for edge '4786965#0').
# (pid=7934) Warning: Discarding unknown compound 'cycleway.opposite_track' in type 'cycleway.opposite_track|highway.residential' (first occurence for edge '4786972#0').
# (pid=7934) Warning: Discarding unknown compound 'cycleway.opposite' in type 'cycleway.opposite|highway.living_street' (first occurence for edge '4795758').
# (pid=7934) Warning: Discarding unknown compound 'cycleway.lane' in type 'cycleway.lane|highway.secondary' (first occurence for edge '100822066').
# (pid=7934) Warning: Removed a road without junctions: -21549451
# (pid=7934) Warning: Removed a road without junctions: 21549451
# (pid=7934) Warning: The traffic light '30624291' does not control any links; it will not be build.
# (pid=7934) Warning: Could not build program '0' for traffic light '30624291'
# (pid=7934) Warning: Minor green from edge '-352962858#0' to edge '4786972#0' exceeds 19.44m/s. Maybe a left-turn lane is missing.
# (pid=7934) Warning: Minor green from edge '352962858#0' to edge '4794820' exceeds 19.44m/s. Maybe a left-turn lane is missing.
# (pid=7934) Warning: Minor green from edge '-352962858#1' to edge '4795742#0' exceeds 19.44m/s. Maybe a left-turn lane is missing.
# (pid=7934) Success.
# (pid=7869) 2020-03-23 16:13:34,921	INFO rollout_worker.py:319 -- Creating policy evaluation worker 1 on CPU (please ignore any CUDA init errors)
# (pid=7869) 2020-03-23 16:13:34.964664: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2
# (pid=7869) 2020-03-23 16:13:35,764	INFO dynamic_tf_policy.py:324 -- Initializing loss function with dummy input:
# (pid=7869)
# (pid=7869) { 'action_prob': <tf.Tensor 'default_policy/action_prob:0' shape=(?,) dtype=float32>,
# (pid=7869)   'actions': <tf.Tensor 'default_policy/actions:0' shape=(?, 0) dtype=float32>,
# (pid=7869)   'advantages': <tf.Tensor 'default_policy/advantages:0' shape=(?,) dtype=float32>,
# (pid=7869)   'behaviour_logits': <tf.Tensor 'default_policy/behaviour_logits:0' shape=(?, 0) dtype=float32>,
# (pid=7869)   'dones': <tf.Tensor 'default_policy/dones:0' shape=(?,) dtype=bool>,
# (pid=7869)   'new_obs': <tf.Tensor 'default_policy/new_obs:0' shape=(?, 10) dtype=float32>,
# (pid=7869)   'obs': <tf.Tensor 'default_policy/observation:0' shape=(?, 10) dtype=float32>,
# (pid=7869)   'prev_actions': <tf.Tensor 'default_policy/action:0' shape=(?, 0) dtype=float32>,
# (pid=7869)   'prev_rewards': <tf.Tensor 'default_policy/prev_reward:0' shape=(?,) dtype=float32>,
# (pid=7869)   'rewards': <tf.Tensor 'default_policy/rewards:0' shape=(?,) dtype=float32>,
# (pid=7869)   'value_targets': <tf.Tensor 'default_policy/value_targets:0' shape=(?,) dtype=float32>,
# (pid=7869)   'vf_preds': <tf.Tensor 'default_policy/vf_preds:0' shape=(?,) dtype=float32>}
# (pid=7869)
# (pid=7934) 2020-03-23 16:13:35,774	INFO rollout_worker.py:319 -- Creating policy evaluation worker 2 on CPU (please ignore any CUDA init errors)
# (pid=7934) 2020-03-23 16:13:35.912553: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2
# (pid=7934) 2020-03-23 16:13:36.774584: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=7934) 2020-03-23 16:13:36.774638: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=7934) 2020-03-23 16:13:36.950805: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=7869) /home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py:100: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
# (pid=7869)   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# (pid=7870) 2020-03-23 16:13:38,221	INFO trainable.py:105 -- _setup took 25.330 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# (pid=7870) 2020-03-23 16:13:38,221	WARNING util.py:47 -- Install gputil for GPU system monitoring.
# (pid=7934) /home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py:100: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
# (pid=7934)   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# (pid=7870) 2020-03-23 16:13:39.219072: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=7870) 2020-03-23 16:13:39.219120: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=7870) 2020-03-23 16:13:39.219165: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=7870) 2020-03-23 16:13:39.409798: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=7870) 2020-03-23 16:13:39.409858: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=7870) 2020-03-23 16:13:39.409891: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=7869) 2020-03-23 16:13:41.753495: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=7869) 2020-03-23 16:13:41.753544: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=7869) 2020-03-23 16:13:41.753570: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=7869) 2020-03-23 16:13:41.753586: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=7869) 2020-03-23 16:13:41.916911: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=7869) 2020-03-23 16:13:41.916962: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=7869) 2020-03-23 16:13:41.916981: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=7869) 2020-03-23 16:13:41.916993: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=7869) 2020-03-23 16:13:41.917030: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=7869) 2020-03-23 16:13:41.917050: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=7869) 2020-03-23 16:13:41.917097: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=7869) 2020-03-23 16:13:41.917124: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=7869) 2020-03-23 16:13:41,918	INFO rollout_worker.py:451 -- Generating sample batch of size 200
# (pid=7869) Warning: Discarding unknown compound 'cycleway.opposite' in type 'cycleway.opposite|highway.residential' (first occurence for edge '4786965#0').
# (pid=7869) Warning: Discarding unknown compound 'cycleway.opposite_track' in type 'cycleway.opposite_track|highway.residential' (first occurence for edge '4786972#0').
# (pid=7869) Warning: Discarding unknown compound 'cycleway.opposite' in type 'cycleway.opposite|highway.living_street' (first occurence for edge '4795758').
# (pid=7869) Warning: Discarding unknown compound 'cycleway.lane' in type 'cycleway.lane|highway.secondary' (first occurence for edge '100822066').
# (pid=7869) Warning: Removed a road without junctions: -21549451
# (pid=7869) Warning: Removed a road without junctions: 21549451
# (pid=7869) Warning: The traffic light '30624291' does not control any links; it will not be build.
# (pid=7869) Warning: Could not build program '0' for traffic light '30624291'
# (pid=7869) Warning: Minor green from edge '-352962858#0' to edge '4786972#0' exceeds 19.44m/s. Maybe a left-turn lane is missing.
# (pid=7869) Warning: Minor green from edge '352962858#0' to edge '4794820' exceeds 19.44m/s. Maybe a left-turn lane is missing.
# (pid=7869) Warning: Minor green from edge '-352962858#1' to edge '4795742#0' exceeds 19.44m/s. Maybe a left-turn lane is missing.
# (pid=7869) Success.
# (pid=7934) 2020-03-23 16:13:43.252203: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=7934) 2020-03-23 16:13:43.252260: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=7934) 2020-03-23 16:13:43.252278: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=7934) 2020-03-23 16:13:43.252291: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=7934) 2020-03-23 16:13:43.252330: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=7934) 2020-03-23 16:13:43.252348: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=7934) Warning: Discarding unknown compound 'cycleway.opposite' in type 'cycleway.opposite|highway.residential' (first occurence for edge '4786965#0').
# (pid=7934) Warning: Discarding unknown compound 'cycleway.opposite_track' in type 'cycleway.opposite_track|highway.residential' (first occurence for edge '4786972#0').
# (pid=7934) Warning: Discarding unknown compound 'cycleway.opposite' in type 'cycleway.opposite|highway.living_street' (first occurence for edge '4795758').
# (pid=7934)
# (pid=7934) Warning: Discarding unknown compound 'cycleway.lane' in type 'cycleway.lane|highway.secondary' (first occurence for edge '100822066').
# (pid=7934) Success.
# (pid=7934) Warning: Removed a road without junctions: -21549451
# (pid=7934) Warning: Removed a road without junctions: 21549451
# (pid=7934) Warning: The traffic light '30624291' does not control any links; it will not be build.
# (pid=7934) Warning: Could not build program '0' for traffic light '30624291'
# (pid=7934) Warning: Minor green from edge '-352962858#0' to edge '4786972#0' exceeds 19.44m/s. Maybe a left-turn lane is missing.
# (pid=7934) Warning: Minor green from edge '352962858#0' to edge '4794820' exceeds 19.44m/s. Maybe a left-turn lane is missing.
# (pid=7934) Warning: Minor green from edge '-352962858#1' to edge '4795742#0' exceeds 19.44m/s. Maybe a left-turn lane is missing.
# (pid=7869) 2020-03-23 16:13:44,030	INFO sampler.py:304 -- Raw obs from env: { 0: { 'agent0': np.ndarray((10,), dtype=float64, min=0.0, max=0.237, mean=0.048)}}
# (pid=7869) 2020-03-23 16:13:44,030	INFO sampler.py:305 -- Info return from env: {0: {'agent0': None}}
# (pid=7869) 2020-03-23 16:13:44,031	INFO sampler.py:403 -- Preprocessed obs: np.ndarray((10,), dtype=float64, min=0.0, max=0.237, mean=0.048)
# (pid=7869) 2020-03-23 16:13:44,031	INFO sampler.py:407 -- Filtered obs: np.ndarray((10,), dtype=float64, min=0.0, max=0.237, mean=0.048)
# (pid=7869) 2020-03-23 16:13:44,033	INFO sampler.py:521 -- Inputs to compute_actions():
# (pid=7869)
# (pid=7869) { 'default_policy': [ { 'data': { 'agent_id': 'agent0',
# (pid=7869)                                   'env_id': 0,
# (pid=7869)                                   'info': None,
# (pid=7869)                                   'obs': np.ndarray((10,), dtype=float64, min=0.0, max=0.237, mean=0.048),
# (pid=7869)                                   'prev_action': np.ndarray((0,), dtype=float32),
# (pid=7869)                                   'prev_reward': 0.0,
# (pid=7869)                                   'rnn_state': []},
# (pid=7869)                         'type': 'PolicyEvalData'}]}
# (pid=7869)
# (pid=7869) 2020-03-23 16:13:44,036	INFO tf_run_builder.py:92 -- Executing TF run without tracing. To dump TF timeline traces to disk, set the TF_TIMELINE_DIR environment variable.
# 2020-03-23 16:13:44,445	ERROR trial_runner.py:550 -- Error processing event.
# Traceback (most recent call last):
#   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/ray/tune/trial_runner.py", line 498, in _process_trial
#     result = self.trial_executor.fetch_result(trial)
#   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/ray/tune/ray_trial_executor.py", line 342, in fetch_result
#     result = ray.get(trial_future[0])
#   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/ray/worker.py", line 2247, in get
#     raise value
# ray.exceptions.RayTaskError: ray_PPO:train() (pid=7870, host=julien-Ubuntu)
#   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/ray/rllib/agents/trainer.py", line 369, in train
#     raise e
#   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/ray/rllib/agents/trainer.py", line 358, in train
#     result = Trainable.train(self)
#   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/ray/tune/trainable.py", line 171, in train
#     result = self._train()
#   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/ray/rllib/agents/trainer_template.py", line 126, in _train
#     fetches = self.optimizer.step()
#   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/ray/rllib/optimizers/multi_gpu_optimizer.py", line 140, in step
#     self.num_envs_per_worker, self.train_batch_size)
#   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/ray/rllib/optimizers/rollout.py", line 29, in collect_samples
#     next_sample = ray_get_and_free(fut_sample)
#   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/ray/rllib/utils/memory.py", line 33, in ray_get_and_free
#     result = ray.get(object_ids)
# ray.exceptions.RayTaskError: ray_RolloutWorker:sample() (pid=7869, host=julien-Ubuntu)
#   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/ray/rllib/evaluation/rollout_worker.py", line 453, in sample
#     batches = [self.input_reader.next()]
#   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/ray/rllib/evaluation/sampler.py", line 56, in next
#     batches = [self.get_data()]
#   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/ray/rllib/evaluation/sampler.py", line 97, in get_data
#     item = next(self.rollout_provider)
#   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/ray/rllib/evaluation/sampler.py", line 334, in _env_runner
#     base_env.send_actions(actions_to_send)
#   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/ray/rllib/env/base_env.py", line 332, in send_actions
#     self.vector_env.vector_step(action_vector)
#   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/ray/rllib/env/vector_env.py", line 110, in vector_step
#     obs, r, done, info = self.envs[i].step(actions[i])
#   File "/home/julien/Documents/flow/flow/envs/base.py", line 368, in step
#     self.k.simulation.simulation_step()
#   File "/home/julien/Documents/flow/flow/core/kernel/simulation/traci.py", line 56, in simulation_step
#     self.kernel_api.simulationStep()
#   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/traci/connection.py", line 323, in simulationStep
#     result = self._sendExact()
#   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/traci/connection.py", line 99, in _sendExact
#     raise FatalTraCIError("connection closed by SUMO")
# traci.exceptions.FatalTraCIError: connection closed by SUMO
# (pid=7869) 2020-03-23 16:13:44.261439: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=7869) 2020-03-23 16:13:44.261498: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=7869) 2020-03-23 16:13:44.261518: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=7869) 2020-03-23 16:13:44.261530: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=7869) 2020-03-23 16:13:44.261561: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=7869) 2020-03-23 16:13:44.261584: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=7869) 2020-03-23 16:13:44,263	INFO sampler.py:548 -- Outputs of compute_actions():
# (pid=7869)
# (pid=7869) { 'default_policy': ( np.ndarray((1, 0), dtype=float32),
# (pid=7869)                       [],
# (pid=7869)                       { 'action_prob': np.ndarray((1,), dtype=float32, min=1.0, max=1.0, mean=1.0),
# (pid=7869)                         'behaviour_logits': np.ndarray((1, 0), dtype=float32),
# (pid=7869)                         'vf_preds': np.ndarray((1,), dtype=float32, min=-0.0, max=-0.0, mean=-0.0)})}
# (pid=7869)
# (pid=7869) 2020-03-23 16:13:44.302237: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=7869) 2020-03-23 16:13:44.302295: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=7869) 2020-03-23 16:13:44.302926: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=7869) 2020-03-23 16:13:44.302974: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=7869) 2020-03-23 16:13:44.302992: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=7869) 2020-03-23 16:13:44.303004: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=7869) 2020-03-23 16:13:44.303027: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=7869) 2020-03-23 16:13:44.303047: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=7869) 2020-03-23 16:13:44.303062: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=7869) 2020-03-23 16:13:44.318487: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=7869) 2020-03-23 16:13:44.318543: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=7869) 2020-03-23 16:13:44.319322: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=7869) 2020-03-23 16:13:44.319356: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=7869) 2020-03-23 16:13:44.319371: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=7869) 2020-03-23 16:13:44.319383: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=7869) 2020-03-23 16:13:44.319502: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=7869) 2020-03-23 16:13:44.319537: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=7869) 2020-03-23 16:13:44.319555: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=7869) 2020-03-23 16:13:44.334783: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=7869) 2020-03-23 16:13:44.334836: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=7869) 2020-03-23 16:13:44.339514: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=7869) 2020-03-23 16:13:44.339552: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=7869) 2020-03-23 16:13:44.339569: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=7869) 2020-03-23 16:13:44.339581: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=7869) 2020-03-23 16:13:44.339608: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=7869) 2020-03-23 16:13:44.339629: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=7869) 2020-03-23 16:13:44.339644: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=7869) 2020-03-23 16:13:44.377336: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=7869) 2020-03-23 16:13:44.377389: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=7869) 2020-03-23 16:13:44.377409: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=7869) 2020-03-23 16:13:44.377428: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=7869) 2020-03-23 16:13:44.377463: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=7869) 2020-03-23 16:13:44.377488: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=7869) 2020-03-23 16:13:44.387165: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=7869) 2020-03-23 16:13:44.387221: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=7869) 2020-03-23 16:13:44.387575: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=7869) 2020-03-23 16:13:44.387598: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=7869) 2020-03-23 16:13:44.387612: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=7869) 2020-03-23 16:13:44.387623: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=7869) 2020-03-23 16:13:44.387643: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=7869) 2020-03-23 16:13:44.387674: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=7869) 2020-03-23 16:13:44.387689: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=7869) 2020-03-23 16:13:44.400469: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=7869) 2020-03-23 16:13:44.400553: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=7869) 2020-03-23 16:13:44.401428: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=7869) 2020-03-23 16:13:44.401481: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=7869) 2020-03-23 16:13:44.401503: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=7869) 2020-03-23 16:13:44.401523: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=7869) 2020-03-23 16:13:44.401554: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=7869) 2020-03-23 16:13:44.401582: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=7869) 2020-03-23 16:13:44.401598: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=7870) 2020-03-23 16:13:44,438	INFO trainer.py:366 -- Worker crashed during call to train(). To attempt to continue training without the failed worker, set `'ignore_worker_failures': True`.
# (pid=7869) 2020-03-23 16:13:44.414299: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=7869) 2020-03-23 16:13:44.414355: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=7869) 2020-03-23 16:13:44.414371: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=7869) 2020-03-23 16:13:44.414384: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=7869) 2020-03-23 16:13:44.414406: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=7869) 2020-03-23 16:13:44.414425: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=7869) 2020-03-23 16:13:44.425544: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=7869) 2020-03-23 16:13:44.425598: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=7869) 2020-03-23 16:13:44.425616: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=7869) 2020-03-23 16:13:44.425629: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=7869) 2020-03-23 16:13:44.425653: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=7869) 2020-03-23 16:13:44.425676: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=7869) Error: attribute 'acceleration_controller' is not declared for element 'flow'
# (pid=7869)  In file '/home/julien/Documents/flow/flow/core/kernel/network/debug/cfg/ISSY_RL_train_20200323-1613321584976412.5714052.rou.xml'
# (pid=7869)  At line/column 10/239.
# (pid=7869)
# (pid=7869) Quitting (on error).
# 2020-03-23 16:13:44,502	INFO trial_runner.py:587 -- Attempting to recover trial state from last checkpoint.
# 2020-03-23 16:13:44,539	WARNING signature.py:108 -- The function with_updates has a **kwargs argument, which is currently not supported.
# 2020-03-23 16:13:44,730	WARNING util.py:145 -- The `process_trial` operation took 0.28756117820739746 seconds to complete, which may be a performance bottleneck.
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 3/3 CPUs, 0/0 GPUs
# Memory usage on this node: 3.5/10.5 GB
# Result logdir: /home/julien/ray_results/ISSY_RL_train
# Number of trials: 1 ({'RUNNING': 1})
# RUNNING trials:
#  - PPO_AccelEnv-v0_0:	RUNNING, 1 failures: /home/julien/ray_results/ISSY_RL_train/PPO_AccelEnv-v0_0_2020-03-23_16-13-05vdou8m0n/error_2020-03-23_16-13-44.txt
#
# (pid=7934) 2020-03-23 16:13:45.764108: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=7934) 2020-03-23 16:13:45.764214: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=7934) 2020-03-23 16:13:45.764245: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=7934) 2020-03-23 16:13:45.764264: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=7934) 2020-03-23 16:13:45.764310: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=7934) 2020-03-23 16:13:45.764331: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=7934) 2020-03-23 16:13:45.780070: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=7934) 2020-03-23 16:13:45.780129: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=7934) 2020-03-23 16:13:45.780148: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=7934) 2020-03-23 16:13:45.780161: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=7934) 2020-03-23 16:13:45.780187: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=7934) 2020-03-23 16:13:45.780207: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=7934) 2020-03-23 16:13:45.800452: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=7934) 2020-03-23 16:13:45.800521: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=7934) 2020-03-23 16:13:45.807991: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=7934) 2020-03-23 16:13:45.808042: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=7934) 2020-03-23 16:13:45.808062: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=7934) 2020-03-23 16:13:45.808076: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=7934) 2020-03-23 16:13:45.808122: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=7934) 2020-03-23 16:13:45.808150: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=7934) 2020-03-23 16:13:45.808165: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=7934) 2020-03-23 16:13:45.821720: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=7934) 2020-03-23 16:13:45.821794: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=7934) 2020-03-23 16:13:45.822240: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=7934) 2020-03-23 16:13:45.822263: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=7934) 2020-03-23 16:13:45.822277: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=7934) 2020-03-23 16:13:45.822288: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=7934) 2020-03-23 16:13:45.822309: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=7934) 2020-03-23 16:13:45.822327: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=7934) 2020-03-23 16:13:45.822341: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=7934) 2020-03-23 16:13:45.836519: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=7934) 2020-03-23 16:13:45.836578: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=7934) 2020-03-23 16:13:45.836972: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=7934) 2020-03-23 16:13:45.836994: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=7934) 2020-03-23 16:13:45.837009: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=7934) 2020-03-23 16:13:45.837021: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=7934) 2020-03-23 16:13:45.837042: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=7934) 2020-03-23 16:13:45.837060: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=7934) 2020-03-23 16:13:45.837088: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=7934) 2020-03-23 16:13:45.852258: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=7934) 2020-03-23 16:13:45.852306: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=7934) 2020-03-23 16:13:45.852556: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=7934) 2020-03-23 16:13:45.852576: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=7934) 2020-03-23 16:13:45.852589: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=7934) 2020-03-23 16:13:45.852599: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=7934) 2020-03-23 16:13:45.852618: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=7934) 2020-03-23 16:13:45.852635: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=7934) 2020-03-23 16:13:45.852647: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=7934) 2020-03-23 16:13:45.868083: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=7934) 2020-03-23 16:13:45.868130: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=7934) 2020-03-23 16:13:45.869518: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=7934) 2020-03-23 16:13:45.869560: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=7934) 2020-03-23 16:13:45.869598: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=7934) 2020-03-23 16:13:45.869621: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=7934) 2020-03-23 16:13:45.869652: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=7934) 2020-03-23 16:13:45.869673: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=7934) 2020-03-23 16:13:45.869688: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=7934) 2020-03-23 16:13:45.890170: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=7934) 2020-03-23 16:13:45.890218: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=7934) 2020-03-23 16:13:45.890234: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=7934) 2020-03-23 16:13:45.890246: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=7934) 2020-03-23 16:13:45.890267: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=7934) 2020-03-23 16:13:45.890289: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=7934) 2020-03-23 16:13:45.904967: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=7934) 2020-03-23 16:13:45.905028: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=7934) 2020-03-23 16:13:45.905455: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=7934) 2020-03-23 16:13:45.905479: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=7934) 2020-03-23 16:13:45.905494: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=7934) 2020-03-23 16:13:45.905506: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=7934) 2020-03-23 16:13:45.905536: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=7934) 2020-03-23 16:13:45.905558: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=7934) 2020-03-23 16:13:45.905573: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=7934) Error: attribute 'acceleration_controller' is not declared for element 'flow'
# (pid=7934)  In file '/home/julien/Documents/flow/flow/core/kernel/network/debug/cfg/ISSY_RL_train_20200323-1613331584976413.413828.rou.xml'
# (pid=7934)  At line/column 10/239.
# (pid=7934)
# (pid=7934) Quitting (on error).
# (pid=8043) 2020-03-23 16:13:53,367	WARNING ppo.py:143 -- FYI: By default, the value function will not share layers with the policy model ('vf_share_layers': False).
# (pid=8043) Warning: Discarding unknown compound 'cycleway.opposite' in type 'cycleway.opposite|highway.residential' (first occurence for edge '4786965#0').
# (pid=8043) Warning: Discarding unknown compound 'cycleway.opposite_track' in type 'cycleway.opposite_track|highway.residential' (first occurence for edge '4786972#0').
# (pid=8043) Warning: Discarding unknown compound 'cycleway.opposite' in type 'cycleway.opposite|highway.living_street' (first occurence for edge '4795758').
# (pid=8043) Warning: Discarding unknown compound 'cycleway.lane' in type 'cycleway.lane|highway.secondary' (first occurence for edge '100822066').
# (pid=8043) Success.
# (pid=8043) Warning: Removed a road without junctions: -21549451
# (pid=8043) Warning: Removed a road without junctions: 21549451
# (pid=8043) Warning: The traffic light '30624291' does not control any links; it will not be build.
# (pid=8043) Warning: Could not build program '0' for traffic light '30624291'
# (pid=8043) Warning: Minor green from edge '-352962858#0' to edge '4786972#0' exceeds 19.44m/s. Maybe a left-turn lane is missing.
# (pid=8043) Warning: Minor green from edge '352962858#0' to edge '4794820' exceeds 19.44m/s. Maybe a left-turn lane is missing.
# (pid=8043) Warning: Minor green from edge '-352962858#1' to edge '4795742#0' exceeds 19.44m/s. Maybe a left-turn lane is missing.
# (pid=8043) 2020-03-23 16:13:55,048	INFO rollout_worker.py:319 -- Creating policy evaluation worker 0 on CPU (please ignore any CUDA init errors)
# (pid=8043) 2020-03-23 16:13:55.053805: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2
# (pid=8043) 2020-03-23 16:13:55.472868: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=8043) 2020-03-23 16:13:55.472981: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=8043) 2020-03-23 16:13:55.533051: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=8043) 2020-03-23 16:13:55,548	INFO dynamic_tf_policy.py:324 -- Initializing loss function with dummy input:
# (pid=8043)
# (pid=8043) { 'action_prob': <tf.Tensor 'default_policy/action_prob:0' shape=(?,) dtype=float32>,
# (pid=8043)   'actions': <tf.Tensor 'default_policy/actions:0' shape=(?, 0) dtype=float32>,
# (pid=8043)   'advantages': <tf.Tensor 'default_policy/advantages:0' shape=(?,) dtype=float32>,
# (pid=8043)   'behaviour_logits': <tf.Tensor 'default_policy/behaviour_logits:0' shape=(?, 0) dtype=float32>,
# (pid=8043)   'dones': <tf.Tensor 'default_policy/dones:0' shape=(?,) dtype=bool>,
# (pid=8043)   'new_obs': <tf.Tensor 'default_policy/new_obs:0' shape=(?, 10) dtype=float32>,
# (pid=8043)   'obs': <tf.Tensor 'default_policy/observation:0' shape=(?, 10) dtype=float32>,
# (pid=8043)   'prev_actions': <tf.Tensor 'default_policy/action:0' shape=(?, 0) dtype=float32>,
# (pid=8043)   'prev_rewards': <tf.Tensor 'default_policy/prev_reward:0' shape=(?,) dtype=float32>,
# (pid=8043)   'rewards': <tf.Tensor 'default_policy/rewards:0' shape=(?,) dtype=float32>,
# (pid=8043)   'value_targets': <tf.Tensor 'default_policy/value_targets:0' shape=(?,) dtype=float32>,
# (pid=8043)   'vf_preds': <tf.Tensor 'default_policy/vf_preds:0' shape=(?,) dtype=float32>}
# (pid=8043)
# (pid=8043) /home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py:100: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
# (pid=8043)   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# (pid=8043) 2020-03-23 16:13:59,334	INFO rollout_worker.py:742 -- Built policy map: {'default_policy': <ray.rllib.policy.tf_policy_template.PPOTFPolicy object at 0x7f082c909048>}
# (pid=8043) 2020-03-23 16:13:59,334	INFO rollout_worker.py:743 -- Built preprocessor map: {'default_policy': <ray.rllib.models.preprocessors.NoPreprocessor object at 0x7f082cba2cc0>}
# (pid=8043) 2020-03-23 16:13:59,334	INFO rollout_worker.py:356 -- Built filter map: {'default_policy': <ray.rllib.utils.filter.NoFilter object at 0x7f082cba2b70>}
# (pid=8043) 2020-03-23 16:13:59,487	INFO multi_gpu_optimizer.py:93 -- LocalMultiGPUOptimizer devices ['/cpu:0']
# 2020-03-23 16:14:17,196	ERROR worker.py:1616 -- print_logs: Error 111 connecting to 10.0.2.15:18277. Connection refused.
# 2020-03-23 16:14:17,199	ERROR worker.py:1716 -- listen_error_messages_raylet: Error 111 connecting to 10.0.2.15:18277. Connection refused.
# 2020-03-23 16:14:17,206	ERROR import_thread.py:89 -- ImportThread: Error 111 connecting to 10.0.2.15:18277. Connection refused.
# (pid=8048) Warning: Discarding unknown compound 'cycleway.opposite' in type 'cycleway.opposite|highway.residential' (first occurence for edge '4786965#0').
# (pid=8048) Warning: Discarding unknown compound 'cycleway.opposite_track' in type 'cycleway.opposite_track|highway.residential' (first occurence for edge '4786972#0').
# (pid=8048) Warning: Discarding unknown compound 'cycleway.opposite' in type 'cycleway.opposite|highway.living_street' (first occurence for edge '4795758').
# (pid=8048) Warning: Discarding unknown compound 'cycleway.lane' in type 'cycleway.lane|highway.secondary' (first occurence for edge '100822066').
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-9986efd91de9> in <module>
#      98         "checkpoint_at_end": True,
#      99         "max_failures": 999,
# --> 100         "stop": {"training_iteration": 5},
#     101     }
#     102 })
#
# ~/anaconda3/envs/flow/lib/python3.6/site-packages/ray/tune/tune.py in run_experiments(experiments, search_alg, scheduler, with_server, server_port, verbose, resume, queue_trials, reuse_actors, trial_executor, raise_on_failed_trial)
#     322             trial_executor=trial_executor,
#     323             raise_on_failed_trial=raise_on_failed_trial,
# --> 324             return_trials=True)
#     325     return trials
#
# ~/anaconda3/envs/flow/lib/python3.6/site-packages/ray/tune/tune.py in run(run_or_experiment, name, stop, config, resources_per_trial, num_samples, local_dir, upload_dir, trial_name_creator, loggers, sync_to_cloud, sync_to_driver, checkpoint_freq, checkpoint_at_end, keep_checkpoints_num, checkpoint_score_attr, global_checkpoint_period, export_formats, max_failures, restore, search_alg, scheduler, with_server, server_port, verbose, resume, queue_trials, reuse_actors, trial_executor, raise_on_failed_trial, return_trials, ray_auto_init, sync_function)
#     242     last_debug = 0
#     243     while not runner.is_finished():
# --> 244         runner.step()
#     245         if time.time() - last_debug > DEBUG_PRINT_INTERVAL:
#     246             if verbose:
#
# ~/anaconda3/envs/flow/lib/python3.6/site-packages/ray/tune/trial_runner.py in step(self)
#     326                 self.trial_executor.start_trial(next_trial)
#     327         elif self.trial_executor.get_running_trials():
# --> 328             self._process_events()  # blocking
#     329         else:
#     330             for trial in self._trials:
#
# ~/anaconda3/envs/flow/lib/python3.6/site-packages/ray/tune/trial_runner.py in _process_events(self)
#     490
#     491     def _process_events(self):
# --> 492         trial = self.trial_executor.get_next_available_trial()  # blocking
#     493         with warn_if_slow("process_trial"):
#     494             self._process_trial(trial)
#
# ~/anaconda3/envs/flow/lib/python3.6/site-packages/ray/tune/ray_trial_executor.py in get_next_available_trial(self)
#     316         # See https://github.com/ray-project/ray/issues/4211 for details.
#     317         start = time.time()
# --> 318         [result_id], _ = ray.wait(shuffled_results)
#     319         wait_time = time.time() - start
#     320         if wait_time > NONTRIVIAL_WAIT_TIME_THRESHOLD_S:
#
# ~/anaconda3/envs/flow/lib/python3.6/site-packages/ray/worker.py in wait(object_ids, num_returns, timeout)
#    2370             timeout_milliseconds,
#    2371             False,
# -> 2372             worker.current_task_id,
#    2373         )
#    2374         return ready_ids, remaining_ids
#
# python/ray/_raylet.pyx in ray._raylet.RayletClient.wait()
#
# python/ray/_raylet.pyx in ray._raylet.check_status()
#
# ~/anaconda3/envs/flow/lib/python3.6/site-packages/ray/exceptions.py in __init__(self, client_exc)
#      84     """
#      85
# ---> 86     def __init__(self, client_exc):
#      87         self.client_exc = client_exc
#      88
#
# KeyboardInterrupt:

# %% [markdown]
# # /!\ Voir tutoriel 10 pour controle des feux
