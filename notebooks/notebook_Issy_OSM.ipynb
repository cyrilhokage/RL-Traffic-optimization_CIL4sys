# %% [markdown]
# # Networks from OpenStreetMap
#
# - import networks from OpenStreetMap.
# - integrate it and run it in Flow.

# %%
# the TestEnv environment is used to simply simulate the network
from flow.envs import TestEnv

# the Experiment class is used for running simulations
from flow.core.experiment import Experiment

# all other imports are standard
from flow.core.params import VehicleParams
from flow.core.params import NetParams, SumoCarFollowingParams
from flow.core.params import InitialConfig
from flow.core.params import EnvParams
from flow.core.params import SumoParams
from flow.controllers import RLController, IDMController
from flow.networks import Network
from flow.core.params import InFlows

# %% [markdown]
# ## 1. Ajouter un flux de voiture

# %% [markdown]
# `IDMController` : The Intelligent Driver Model is a car-following model specifying vehicle dynamics by a differential equation for acceleration $\dot{v}$.
#
# `RLController` : a trainable autuonomous vehicle whose actions are dictated by an RL agent.

# %%
vehicles = VehicleParams()
vehicles.add("human",acceleration_controller=(IDMController, {}))
vehicles.add("rl",acceleration_controller=(RLController, {}),num_vehicles=2)

# %% [markdown]
# - `vehs_per_hour`: nombre de vehicule par heure, uniformément espacés. Par exemple, comme il y a $60 \times 60 = 3600$ secondes dans une heure, le parametre $\frac{3600}{5}=720$ va faire rentrer des vehicules dans le network toutes les $5$ secondes.
#
# - `probability`: c'est la probabilité qu'un véhicule entre dans le network toutes les secondes. Par exemple, si on la fixe à $0.2$, alors chaque seconde de la simulation un véhicule aura $\frac{1}{5}$ chance d'entrer dans le network
#
# - `period`: C'est le temps en secondes entre 2 véhicules qui sont insérés. Par exemple, le fixer à $5$ ferait rentrer des véhicules dans le network toutes les $5$ secondes (ce qui équivaut à mettre `vehs_per_hour` à $720$).
#
# <font color='red'>
# $\rightarrow$ Exactement 1 seul de ces 3 paramètres doit être configurer !
# </font>

# %%
inflow = InFlows()

inflow.add(veh_type      = "human",
           edge          = "4794817",
           probability   = 0.3, 
           depart_speed  = 7,
           depart_lane   = "random")

inflow.add(veh_type      = "human",
           edge          = "4783299#0",
           probability   = 0.2,
           depart_speed  = 7,
           depart_lane   = "random")

inflow.add(veh_type       = "human",
           edge           = "-100822066",
           probability    = 0.25,
           depart_speed   = 7,
           depart_lane    = "random")

inflow.add(veh_type       = "rl",
           edge           = "-100822066",
           probability    = 0.05,
           depart_speed   = 7,
           depart_lane    = "random",
           color          = "blue")

inflow.add(veh_type       = "human",
           edge          = "155558218",
           probability   = 0.2,
           depart_speed  = 7,
           depart_lane   = "random")

# %% [markdown]
# ## 2. Créer des itinéraires

# %%
# Specifie les noms des edges du network dont les vehicules peuvent être originaire
EDGES_DISTRIBUTION = [
    "-100822066",
    "4794817",
    "4783299#0",
    "155558218",
]

# %%
# créer une nouvelle classe Network pour spécifier les itinéraires possibles
class IssyOSMNetwork(Network):

    def specify_routes(self, net_params):
        return {
            "-100822066": [ #N
                "-100822066",
                "-352962858#1",
                "-352962858#0",
                "-4786940#1",
                 "-4786940#0",
            ],
            
            "4794817" : [ #Loop
                "4794817",
                "4786972#0",
                "4786972#1",
                "4786972#2",
                "4786965#1",
                "4786965#2",
                "4786965#3",
                "4795729",
                "-352962858#1",
                "4795742#0",
                "4795742#1",
                "4786965#3",
                "4786965#4",
                "4786965#5",
            ],
            
            "4783299#0": [    #E
                "4783299#0",
                "4783299#1",
                "4783299#2",
                "4783299#3",
                "4783299#4",
                "4783299#5",
                "4783299#6",
                "4786940#0",
                "4786940#1",
                "352962858#0",
                "352962858#1",
                "100822066",
            ],
            
            "155558218": [
                "155558218",
                "4786940#1",
                "352962858#0",
                "352962858#1",
                "100822066",
            ],     
        }

# %% [markdown]
# # Personnaliser un Environnement pour le RL
#
# More accessor objects and methods can be found within the Flow documentation at: http://berkeleyflow.readthedocs.io/en/latest/

# %%
# import the base environment class
from flow.envs import Env
from gym.spaces.box import Box
from gym.spaces import Tuple
import numpy as np

# %% [markdown]
# ## definition de la classe environnement

# %%
class myEnv(Env):
    pass

# %% [markdown]
# ## fonction action_space
# 2 actions possibles pour chaque véhicule RL : +1 acceleration ou -1 acceleration

# %%
class myEnv(myEnv): # update my environment class

    @property
    def action_space(self):
        num_actions = self.initial_vehicles.num_rl_vehicles
        accel_ub = self.env_params.additional_params["max_accel"]
        accel_lb = - abs(self.env_params.additional_params["max_decel"])

        return Box(low=accel_lb,
                   high=accel_ub,
                   shape=(num_actions,))

# %% [markdown]
# ## observation_space
# 2 valeurs observé pour chaque véhicule: sa **position** et sa **vitesse**. En conséquence, nous avons besoin d'un espace d'observation qui est *deux fois plus grand que le nombre de véhicules* dans le network.

# %%
class myEnv(myEnv):  # update my environment class

    @property
    def observation_space(self):
        return Box(
            low=0,
            high=float("inf"),
            shape=(2*self.initial_vehicles.num_vehicles,))

# %% [markdown]
# ## apply_rl_actions
# `apply_rl_actions` : transforme les commandes de l'agent RL en actions réelles du simulateur.
#
# Pour notre exemple, l'agent RL peut spécifier que les accélérations des véhicules RL avec la fonction **apply_acceleration**

# %%
class myEnv(myEnv):  # update my environment class

    def _apply_rl_actions(self, rl_actions):
        # the names of all autonomous (RL) vehicles in the network
        rl_ids = self.k.vehicle.get_rl_ids()

        # use the base environment method to convert actions into accelerations for the rl vehicles
        self.k.vehicle.apply_acceleration(rl_ids, rl_actions)

# %% [markdown]
# ## get_state
#
# `get_state` : extrait des features de l'environnement et fournit ensuite des entrées à la stratégie fournie par l'agent RL.

# %%
class myEnv(myEnv):  # update my environment class

    def get_state(self, **kwargs):
        # the get_ids() method is used to get the names of all vehicles in the network
        ids = self.k.vehicle.get_ids()

        # we use the get_absolute_position method to get the positions of all vehicles
        pos = [self.k.vehicle.get_x_by_id(veh_id) for veh_id in ids]

        # we use the get_speed method to get the velocities of all vehicles
        vel = [self.k.vehicle.get_speed(veh_id) for veh_id in ids]

        # the speeds and positions are concatenated to produce the state
        return np.concatenate((pos, vel))

# %% [markdown]
# ## compute_reward
#
# `compute_reward` : renvoie la récompense associée à un état donné.
#
# Ici, la fonction de récompense est la **vitesse moyenne de tous les véhicules actuellement sur le réseau**.

# %%
class myEnv(myEnv):  # update my environment class

    def compute_reward(self, rl_actions, **kwargs):
        # the get_ids() method is used to get the names of all vehicles in the network
        ids = self.k.vehicle.get_ids()

        # we next get a list of the speeds of all vehicles in the network
        speeds = self.k.vehicle.get_speed(ids)

        # finally, we return the average of all these speeds as the reward
        return np.mean(speeds)

# %% [markdown]
# # Testing

# %%
HORIZON = 200

# %%
from flow.core.experiment import Experiment
from flow.core.params import SumoParams, EnvParams, InitialConfig, NetParams
from flow.core.params import VehicleParams

# %% [markdown]
# ```python
# # SUMO PARAM
# sumo_params = SumoParams(sim_step=0.1, render=True)
#
# # create VEHICLE
# vehicles = VehicleParams()
# vehicles.add(veh_id="human",
#              acceleration_controller=(IDMController, {}),
#              num_vehicles=22)
#
# # ENVIRONMENT PARAM
# env_params = EnvParams(additional_params=ADDITIONAL_ENV_PARAMS, horizon=HORIZON)
#
# # NETWORK PARAM
# additional_net_params = ADDITIONAL_NET_PARAMS.copy()
# net_params = NetParams(additional_params=additional_net_params, inflows=inflow, osm_path='issy.osm')
#
# # NETWORK
# network = IssyOSMNetwork
#
# # INITIAL CONFIG
# initial_config = InitialConfig(edges_distribution=EDGES_DISTRIBUTION) #spacing="random",
#
# # dictionnaire FLOW_PARAM
# flow_params = dict( exp_tag  = 'ISSY_RL_test',
#                     env_name = myEnv,  # using my new environment for the simulation
#                     network  = network,
#                     simulator= 'traci',
#                     sim      = sumo_params,
#                     env      = env_params,
#                     net      = net_params,
#                     veh      = vehicles,
#                     initial  = initial_config)
#
# # create EXPERIMENT with class created
# exp = Experiment(flow_params)
#
# # RUN SIMULATION SUMO
# _ = exp.run(1)
# ```

# %% [markdown]
# # Training
#
# Pour qu'un environnement puisse être entrainé, l'environnement doit être accessible via l'importation à partir de flow.envs.
#
#
# <font color='red'>
# Copier l'environnement créé dans un fichier .py et on importe l'environnement dans `flow.envs.__init__.py`.
# Mettre le chemin absolu du fichier .osm .
# </font>

# %%
# NOTE: only runs if the above procedure have been performed
#from flow.envs import AccelEnv as myEnv
#ADDITIONAL_ENV_PARAMS = {"target_velocity": 20,"sort_vehicles": False,"max_accel": 1,"max_decel": 1}
from myenv import myEnv as myEnv
ADDITIONAL_ENV_PARAMS = {"max_accel": 1, "max_decel": 1}

# %%
import json
import ray
from ray.rllib.agents.registry import get_agent_class
from ray.tune import run_experiments
from ray.tune.registry import register_env

from flow.networks.ring import ADDITIONAL_NET_PARAMS
from flow.utils.registry import make_create_env
from flow.utils.rllib import FlowParamsEncoder
from flow.core.params import VehicleParams, SumoCarFollowingParams


# number of rollouts per training iteration
N_ROLLOUTS = 10
# number of parallel workers
N_CPUS = 2

# SUMO PARAM
sumo_params = SumoParams(sim_step=0.1, render=False, restart_instance=True)

# ENVIRONMENT PARAM
env_params = EnvParams(additional_params=ADDITIONAL_ENV_PARAMS, horizon=HORIZON)

# NETWORK PARAM
additional_net_params = ADDITIONAL_NET_PARAMS.copy()
path_file  = '/home/julien/projet_CIL4SYS/issy.osm'
net_params = NetParams(inflows=inflow, osm_path=path_file) 

# NETWORK
network = IssyOSMNetwork

# INITIAL CONFIG
initial_config = InitialConfig(edges_distribution=EDGES_DISTRIBUTION)

vehicles = VehicleParams()
vehicles.add(veh_id="human", acceleration_controller=(IDMController, {}), num_vehicles=5)

flow_params = dict( exp_tag   = "ISSY_RL_train", 
                    env_name  = myEnv,  
                    network   = IssyOSMNetwork,
                    simulator = 'traci', # simulator that is used by the experiment
                    sim       = sumo_params,
                    env       = env_params,
                    net       = net_params,
                    veh       = vehicles,
                    initial   = initial_config)

def setup_exps():
    """Return the relevant components of an RLlib experiment.

    Returns
    -------
    str
        name of the training algorithm
    str
        name of the gym environment to be trained
    dict
        training configuration parameters
    """
    alg_run   = "PPO"
    agent_cls = get_agent_class(alg_run)
    config    = agent_cls._default_config.copy()
    config["num_workers"]      = N_CPUS
    config["train_batch_size"] = HORIZON * N_ROLLOUTS
    config["gamma"]            = 0.999  # discount rate
    config["use_gae"]          = True
    config["lambda"]           = 0.97
    config["kl_target"]        = 0.02
    config["num_sgd_iter"]     = 10
    config['clip_actions']     = False  # FIXME(ev) temporary ray bug
    config["horizon"]          = HORIZON
    config["model"].update({"fcnet_hiddens": [3, 3]})
    
    # save the flow params for replay
    flow_json = json.dumps( flow_params, cls=FlowParamsEncoder, sort_keys=True, indent=4)
    config['env_config']['flow_params'] = flow_json
    config['env_config']['run'] = alg_run

    create_env, gym_name = make_create_env(params=flow_params, version=0)

    # Register as rllib env
    register_env(gym_name, create_env)
    
    return alg_run, gym_name, config


alg_run, gym_name, config = setup_exps()

ray.init(num_cpus=N_CPUS + 1)

trials = run_experiments({
    flow_params["exp_tag"]: {
        "run": alg_run,
        "env": gym_name,
        "config": {**config},
        "checkpoint_freq": 500,
        "checkpoint_at_end": True,
        "max_failures": 999,
        "stop": {"training_iteration": 5},
    }
})
# Out:
# 2020-03-24 11:58:53,433	INFO node.py:498 -- Process STDOUT and STDERR is being redirected to /tmp/ray/session_2020-03-24_11-58-53_432989_4325/logs.
# 2020-03-24 11:58:53,558	INFO services.py:409 -- Waiting for redis server at 127.0.0.1:16702 to respond...
# 2020-03-24 11:58:53,696	INFO services.py:409 -- Waiting for redis server at 127.0.0.1
INFO sampler.py:403 -- Preprocessed obs: np.ndarray((10,), dtype=float64, min=0.0, max=734.822, mean=148.747)
# (pid=4361) 2020-03-24 11:59:31,124	INFO sampler.py:407 -- Filtered obs: np.ndarray((10,), dtype=float64, min=0.0, max=734.822, mean=148.747)
# (pid=4361) 2020-03-24 11:59:31,125	INFO sampler.py:521 -- Inputs to compute_actions():
# (pid=4361)
# (pid=4361) { 'default_policy': [ { 'data': { 'agent_id': 'agent0',
# (pid=4361)                                   'env_id': 0,
# (pid=4361)                                   'info': None,
# (pid=4361)                                   'obs': np.ndarray((10,), dtype=float64, min=0.0, max=734.822, mean=148.747),
# (pid=4361)                                   'prev_action': np.ndarray((0,), dtype=float32),
# (pid=4361)                                   'prev_reward': 0.0,
# (pid=4361)                                   'rnn_state': []},
# (pid=4361)                         'type': 'PolicyEvalData'}]}
# (pid=4361)
# (pid=4361) 2020-03-24 11:59:31,125	INFO tf_run_builder.py:92 -- Executing TF run without tracing. To dump TF timeline traces to disk, set the TF_TIMELINE_DIR environment variable.
# (pid=4430) 2020-03-24 11:59:31.111646: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=4430) 2020-03-24 11:59:31.111685: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=4430) 2020-03-24 11:59:31.111697: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=4430) 2020-03-24 11:59:31.111706: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=4430) 2020-03-24 11:59:31.111729: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=4430) 2020-03-24 11:59:31.111741: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# 2020-03-24 11:59:31,455	ERROR trial_runner.py:550 -- Error processing event.
# Traceback (most recent call last):
#   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/ray/tune/trial_runner.py", line 498, in _process_trial
#     result = self.trial_executor.fetch_result(trial)
#   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/ray/tune/ray_trial_executor.py", line 342, in fetch_result
#     result = ray.get(trial_future[0])
#   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/ray/worker.py", line 2247, in get
#     raise value
# ray.exceptions.RayTaskError: ray_PPO:train() (pid=4360, host=julien-Ubuntu)
#   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/ray/rllib/agents/trainer.py", line 369, in train
#     raise e
#   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/ray/rllib/agents/trainer.py", line 358, in train
#     result = Trainable.train(self)
#   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/ray/tune/trainable.py", line 171, in train
#     result = self._train()
#   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/ray/rllib/agents/trainer_template.py", line 126, in _train
#     fetches = self.optimizer.step()
#   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/ray/rllib/optimizers/multi_gpu_optimizer.py", line 140, in step
#     self.num_envs_per_worker, self.train_batch_size)
#   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/ray/rllib/optimizers/rollout.py", line 29, in collect_samples
#     next_sample = ray_get_and_free(fut_sample)
#   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/ray/rllib/utils/memory.py", line 33, in ray_get_and_free
#     result = ray.get(object_ids)
# ray.exceptions.RayTaskError: ray_RolloutWorker:sample() (pid=4361, host=julien-Ubuntu)
#   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/ray/rllib/evaluation/rollout_worker.py", line 453, in sample
#     batches = [self.input_reader.next()]
#   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/ray/rllib/evaluation/sampler.py", line 56, in next
#     batches = [self.get_data()]
#   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/ray/rllib/evaluation/sampler.py", line 97, in get_data
#     item = next(self.rollout_provider)
#   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/ray/rllib/evaluation/sampler.py", line 334, in _env_runner
#     base_env.send_actions(actions_to_send)
#   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/ray/rllib/env/base_env.py", line 332, in send_actions
#     self.vector_env.vector_step(action_vector)
#   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/ray/rllib/env/vector_env.py", line 110, in vector_step
#     obs, r, done, info = self.envs[i].step(actions[i])
#   File "/home/julien/Documents/flow/flow/envs/base.py", line 368, in step
#     self.k.simulation.simulation_step()
#   File "/home/julien/Documents/flow/flow/core/kernel/simulation/traci.py", line 56, in simulation_step
#     self.kernel_api.simulationStep()
#   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/traci/connection.py", line 323, in simulationStep
#     result = self._sendExact()
#   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/traci/connection.py", line 99, in _sendExact
#     raise FatalTraCIError("connection closed by SUMO")
# traci.exceptions.FatalTraCIError: connection closed by SUMO
#
#
# 2020-03-24 11:59:31,498	INFO trial_runner.py:587 -- Attempting to recover trial state from last checkpoint.
# 2020-03-24 11:59:31,534	WARNING signature.py:108 -- The function with_updates has a **kwargs argument, which is currently not supported.
# (pid=4361) 2020-03-24 11:59:31.329626: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=4361) 2020-03-24 11:59:31.329677: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=4361) 2020-03-24 11:59:31.329693: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=4361) 2020-03-24 11:59:31.329704: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=4361) 2020-03-24 11:59:31.329728: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=4361) 2020-03-24 11:59:31.329748: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=4361) 2020-03-24 11:59:31,331	INFO sampler.py:548 -- Outputs of compute_actions():
# (pid=4361)
# (pid=4361) { 'default_policy': ( np.ndarray((1, 0), dtype=float32),
# (pid=4361)                       [],
# (pid=4361)                       { 'action_prob': np.ndarray((1,), dtype=float32, min=1.0, max=1.0, mean=1.0),
# (pid=4361)                         'behaviour_logits': np.ndarray((1, 0), dtype=float32),
# (pid=4361)                         'vf_preds': np.ndarray((1,), dtype=float32, min=0.007, max=0.007, mean=0.007)})}
# (pid=4361)
# (pid=4361) 2020-03-24 11:59:31.339384: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=4361) 2020-03-24 11:59:31.339427: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=4361) 2020-03-24 11:59:31.339843: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=4361) 2020-03-24 11:59:31.339866: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=4361) 2020-03-24 11:59:31.339880: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=4361) 2020-03-24 11:59:31.339893: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=4361) 2020-03-24 11:59:31.339924: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=4361) 2020-03-24 11:59:31.339943: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=4361) 2020-03-24 11:59:31.339957: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=4361) 2020-03-24 11:59:31.346614: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=4361) 2020-03-24 11:59:31.346720: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=4361) 2020-03-24 11:59:31.348981: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=4361) 2020-03-24 11:59:31.349029: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=4361) 2020-03-24 11:59:31.349094: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=4361) 2020-03-24 11:59:31.349115: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=4361) 2020-03-24 11:59:31.349138: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=4361) 2020-03-24 11:59:31.349163: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=4361) 2020-03-24 11:59:31.349178: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=4361) 2020-03-24 11:59:31.359443: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=4361) 2020-03-24 11:59:31.359499: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=4361) 2020-03-24 11:59:31.360128: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=4361) 2020-03-24 11:59:31.360175: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=4361) 2020-03-24 11:59:31.360193: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=4361) 2020-03-24 11:59:31.360207: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=4361) 2020-03-24 11:59:31.360241: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=4361) 2020-03-24 11:59:31.360264: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=4361) 2020-03-24 11:59:31.360279: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=4361) 2020-03-24 11:59:31.371220: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=4361) 2020-03-24 11:59:31.371269: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=4361) 2020-03-24 11:59:31.371286: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=4361) 2020-03-24 11:59:31.371297: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=4361) 2020-03-24 11:59:31.371317: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=4361) 2020-03-24 11:59:31.371336: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=4361) 2020-03-24 11:59:31.380149: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=4361) 2020-03-24 11:59:31.380203: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=4361) 2020-03-24 11:59:31.381745: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=4361) 2020-03-24 11:59:31.381787: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=4361) 2020-03-24 11:59:31.381799: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=4361) 2020-03-24 11:59:31.381808: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=4361) 2020-03-24 11:59:31.381825: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=4361) 2020-03-24 11:59:31.381839: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=4361) 2020-03-24 11:59:31.381850: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=4361) 2020-03-24 11:59:31.395460: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=4361) 2020-03-24 11:59:31.395523: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=4361) 2020-03-24 11:59:31.396786: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=4361) 2020-03-24 11:59:31.396833: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=4361) 2020-03-24 11:59:31.396852: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=4361) 2020-03-24 11:59:31.396866: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=4361) 2020-03-24 11:59:31.396889: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=4361) 2020-03-24 11:59:31.397071: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=4361) 2020-03-24 11:59:31.397098: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=4360) 2020-03-24 11:59:31,444	INFO trainer.py:366 -- Worker crashed during call to train(). To attempt to continue training without the failed worker, set `'ignore_worker_failures': True`.
# (pid=4361) 2020-03-24 11:59:31.411045: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=4361) 2020-03-24 11:59:31.411098: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=4361) 2020-03-24 11:59:31.412465: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=4361) 2020-03-24 11:59:31.412508: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=4361) 2020-03-24 11:59:31.412856: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=4361) 2020-03-24 11:59:31.412889: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=4361) 2020-03-24 11:59:31.413049: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=4361) 2020-03-24 11:59:31.413080: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=4361) 2020-03-24 11:59:31.413107: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=4361) 2020-03-24 11:59:31.422440: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=4361) 2020-03-24 11:59:31.422489: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=4361) 2020-03-24 11:59:31.422503: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=4361) 2020-03-24 11:59:31.422514: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=4361) 2020-03-24 11:59:31.422542: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=4361) 2020-03-24 11:59:31.422561: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=4361) Error: The vehicle type 'rl' for flow 'flow_30' is not known.
# (pid=4361) Quitting (on error).
# 2020-03-24 11:59:31,699	WARNING util.py:145 -- The `process_trial` operation took 0.24705767631530762 seconds to complete, which may be a performance bottleneck.
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 3/3 CPUs, 0/0 GPUs
# Memory usage on this node: 2.6/10.5 GB
# Result logdir: /home/julien/ray_results/ISSY_RL_train
# Number of trials: 1 ({'RUNNING': 1})
# RUNNING trials:
#  - PPO_myEnv-v0_0:	RUNNING, 1 failures: /home/julien/ray_results/ISSY_RL_train/PPO_myEnv-v0_0_2020-03-24_11-58-54d79qpqmw/error_2020-03-24_11-59-31.txt
#
# (pid=4430) Warning: Discarding unknown compound 'cycleway.opposite' in type 'cycleway.opposite|highway.residential' (first occurence for edge '4786965#0').
# (pid=4430) Warning: Discarding unknown compound 'cycleway.opposite_track' in type 'cycleway.opposite_track|highway.residential' (first occurence for edge '4786972#0').
# (pid=4430) Warning: Discarding unknown compound 'cycleway.opposite' in type 'cycleway.opposite|highway.living_street' (first occurence for edge '4795758').
# (pid=4430) Warning: Discarding unknown compound 'cycleway.lane' in type 'cycleway.lane|highway.secondary' (first occurence for edge '100822066').
# (pid=
   'advantages': <tf.Tensor 'default_policy/advantages:0' shape=(?,) dtype=float32>,
# (pid=4633)   'behaviour_logits': <tf.Tensor 'default_policy/behaviour_logits:0' shape=(?, 0) dtype=float32>,
# (pid=4633)   'dones': <tf.Tensor 'default_policy/dones:0' shape=(?,) dtype=bool>,
# (pid=4633)   'new_obs': <tf.Tensor 'default_policy/new_obs:0' shape=(?, 10) dtype=float32>,
# (pid=4633)   'obs': <tf.Tensor 'default_policy/observation:0' shape=(?, 10) dtype=float32>,
# (pid=4633)   'prev_actions': <tf.Tensor 'default_policy/action:0' shape=(?, 0) dtype=float32>,
# (pid=4633)   'prev_rewards': <tf.Tensor 'default_policy/prev_reward:0' shape=(?,) dtype=float32>,
# (pid=4633)   'rewards': <tf.Tensor 'default_policy/rewards:0' shape=(?,) dtype=float32>,
# (pid=4633)   'value_targets': <tf.Tensor 'default_policy/value_targets:0' shape=(?,) dtype=float32>,
# (pid=4633)   'vf_preds': <tf.Tensor 'default_policy/vf_preds:0' shape=(?,) dtype=float32>}
# (pid=4633)
# (pid=4633) /home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py:100: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
# (pid=4633)   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# (pid=4633) 2020-03-24 12:00:23,608	INFO rollout_worker.py:742 -- Built policy map: {'default_policy': <ray.rllib.policy.tf_policy_template.PPOTFPolicy object at 0x7f5fe7d681d0>}
# (pid=4633) 2020-03-24 12:00:23,608	INFO rollout_worker.py:743 -- Built preprocessor map: {'default_policy': <ray.rllib.models.preprocessors.NoPreprocessor object at 0x7f5fe880be48>}
# (pid=4633) 2020-03-24 12:00:23,608	INFO rollout_worker.py:356 -- Built filter map: {'default_policy': <ray.rllib.utils.filter.NoFilter object at 0x7f5fe880bcf8>}
# (pid=4633) 2020-03-24 12:00:23,729	INFO multi_gpu_optimizer.py:93 -- LocalMultiGPUOptimizer devices ['/cpu:0']
# (pid=4786) Warning: Discarding unknown compound 'cycleway.opposite' in type 'cycleway.opposite|highway.residential' (first occurence for edge '4786965#0').
# (pid=4786) Warning: Discarding unknown compound 'cycleway.opposite_track' in type 'cycleway.opposite_track|highway.residential' (first occurence for edge '4786972#0').
# (pid=4786) Warning: Discarding unknown compound 'cycleway.opposite' in type 'cycleway.opposite|highway.living_street' (first occurence for edge '4795758').
# (pid=4786) Warning: Discarding unknown compound 'cycleway.lane' in type 'cycleway.lane|highway.secondary' (first occurence for edge '100822066').
# (pid=4786) Warning: Removed a road without junctions: -21549451
# (pid=4786) Warning: Removed a road without junctions: 21549451
# (pid=4786) Warning: The traffic light '30624291' does not control any links; it will not be build.
# (pid=4786) Warning: Could not build program '0' for traffic light '30624291'
# (pid=4786) Warning: Minor green from edge '-352962858#0' to edge '4786972#0' exceeds 19.44m/s. Maybe a left-turn lane is missing.
# (pid=4786) Warning: Minor green from edge '352962858#0' to edge '4794820' exceeds 19.44m/s. Maybe a left-turn lane is missing.
# (pid=4786) Warning: Minor green from edge '-352962858#1' to edge '4795742#0' exceeds 19.44m/s. Maybe a left-turn lane is missing.
# (pid=4786) Success.
# (pid=4787) Warning: Discarding unknown compound 'cycleway.opposite' in type 'cycleway.opposite|highway.residential' (first occurence for edge '4786965#0').
# (pid=4787) Warning: Discarding unknown compound 'cycleway.opposite_track' in type 'cycleway.opposite_track|highway.residential' (first occurence for edge '4786972#0').
# (pid=4787) Warning: Discarding unknown compound 'cycleway.opposite' in type 'cycleway.opposite|highway.living_street' (first occurence for edge '4795758').
# (pid=4787) Warning: Discarding unknown compound 'cycleway.lane' in type 'cycleway.lane|highway.secondary' (first occurence for edge '100822066').
# (pid=4787) Warning: Removed a road without junctions: -21549451
# (pid=4787) Warning: Removed a road without junctions: 21549451
# (pid=4787) Warning: The traffic light '30624291' does not control any links; it will not be build.
# (pid=4787) Warning: Could not build program '0' for traffic light '30624291'
# (pid=4787) Warning: Minor green from edge '-352962858#0' to edge '4786972#0' exceeds 19.44m/s. Maybe a left-turn lane is missing.
# (pid=4787) Warning: Minor green from edge '352962858#0' to edge '4794820' exceeds 19.44m/s. Maybe a left-turn lane is missing.
# (pid=4787) Warning: Minor green from edge '-352962858#1' to edge '4795742#0' exceeds 19.44m/s. Maybe a left-turn lane is missing.
# (pid=4787) Success.
# (pid=4786) 2020-03-24 12:00:40,823	INFO rollout_worker.py:319 -- Creating policy evaluation worker 1 on CPU (please ignore any CUDA init errors)
# (pid=4786) 2020-03-24 12:00:40.850099: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2
# (pid=4787) 2020-03-24 12:00:41,126	INFO rollout_worker.py:319 -- Creating policy evaluation worker 2 on CPU (please ignore any CUDA init errors)
# (pid=4787) 2020-03-24 12:00:41.289000: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2
# (pid=4633) 2020-03-24 12:00:41,887	INFO trainable.py:105 -- _setup took 26.022 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# (pid=4633) 2020-03-24 12:00:41,888	WARNING util.py:47 -- Install gputil for GPU system monitoring.
# (pid=4786) 2020-03-24 12:00:41,921	INFO dynamic_tf_policy.py:324 -- Initializing loss function with dummy input:
# (pid=4786)
# (pid=4786) { 'action_prob': <tf.Tensor 'default_policy/action_prob:0' shape=(?,) dtype=float32>,
# (pid=4786)   'actions': <tf.Tensor 'default_policy/actions:0' shape=(?, 0) dtype=float32>,
# (pid=4786)   'advantages': <tf.Tensor 'default_policy/advantages:0' shape=(?,) dtype=float32>,
# (pid=4786)   'behaviour_logits': <tf.Tensor 'default_policy/behaviour_logits:0' shape=(?, 0) dtype=float32>,
# (pid=4786)   'dones': <tf.Tensor 'default_policy/dones:0' shape=(?,) dtype=bool>,
# (pid=4786)   'new_obs': <tf.Tensor 'default_policy/new_obs:0' shape=(?, 10) dtype=float32>,
# (pid=4786)   'obs': <tf.Tensor 'default_policy/observation:0' shape=(?, 10) dtype=float32>,
# (pid=4786)   'prev_actions': <tf.Tensor 'default_policy/action:0' shape=(?, 0) dtype=float32>,
# (pid=4786)   'prev_rewards': <tf.Tensor 'default_policy/prev_reward:0' shape=(?,) dtype=float32>,
# (pid=4786)   'rewards': <tf.Tensor 'default_policy/rewards:0' shape=(?,) dtype=float32>,
# (pid=4786)   'value_targets': <tf.Tensor 'default_policy/value_targets:0' shape=(?,) dtype=float32>,
# (pid=4786)   'vf_preds': <tf.Tensor 'default_policy/vf_preds:0' shape=(?,) dtype=float32>}
# (pid=4786)
# (pid=4633) 2020-03-24 12:00:43.075167: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=4633) 2020-03-24 12:00:43.075223: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=4633) 2020-03-24 12:00:43.075266: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=4633) 2020-03-24 12:00:43.289715: E tensorflow/core/common_runtime/bfc_allocator.cc:246] tried to allocate 0 bytes
# (pid=4633) 2020-03-24 12:00:43.289756: W tensorflow/core/common_runtime/allocator_retry.cc:32] Request to allocate 0 bytes
# (pid=4633) 2020-03-24 12:00:43.289775: E tensorflow/core/common_runtime/bfc_allocator.cc:381] tried to deallocate nullptr
# (pid=4786) /home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py:100: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
# (pid=4786)   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# 2020-03-24 12:00:43,735	ERROR worker.py:1616 -- print_logs: Error 111 connecting to 10.0.2.15:16702. Connection refused.
# 2020-03-24 12:00:43,738	ERROR import_thread.py:89 -- ImportThread: Error 111 connecting to 10.0.2.15:16702. Connection refused.
# 2020-03-24 12:00:43,740	ERROR worker.py:1716 -- listen_error_messages_raylet: Error 111 connecting to 10.0.2.15:16702. Connection refused.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-6d6727d12fc3> in <module>
#      97         "checkpoint_at_end": True,
#      98         "max_failures": 999,
# ---> 99         "stop": {"training_iteration": 5},
#     100     }
#     101 })
#
# ~/anaconda3/envs/flow/lib/python3.6/site-packages/ray/tune/tune.py in run_experiments(experiments, search_alg, scheduler, with_server, server_port, verbose, resume, queue_trials, reuse_actors, trial_executor, raise_on_failed_trial)
#     322             trial_executor=trial_executor,
#     323             raise_on_failed_trial=raise_on_failed_trial,
# --> 324             return_trials=True)
#     325     return trials
#
# ~/anaconda3/envs/flow/lib/python3.6/site-packages/ray/tune/tune.py in run(run_or_experiment, name, stop, config, resources_per_trial, num_samples, local_dir, upload_dir, trial_name_creator, loggers, sync_to_cloud, sync_to_driver, checkpoint_freq, checkpoint_at_end, keep_checkpoints_num, checkpoint_score_attr, global_checkpoint_period, export_formats, max_failures, restore, search_alg, scheduler, with_server, server_port, verbose, resume, queue_trials, reuse_actors, trial_executor, raise_on_failed_trial, return_trials, ray_auto_init, sync_function)
#     242     last_debug = 0
#     243     while not runner.is_finished():
# --> 244         runner.step()
#     245         if time.time() - last_debug > DEBUG_PRINT_INTERVAL:
#     246             if verbose:
#
# ~/anaconda3/envs/flow/lib/python3.6/site-packages/ray/tune/trial_runner.py in step(self)
#     326                 self.trial_executor.start_trial(next_trial)
#     327         elif self.trial_executor.get_running_trials():
# --> 328             self._process_events()  # blocking
#     329         else:
#     330             for trial in self._trials:
#
# ~/anaconda3/envs/flow/lib/python3.6/site-packages/ray/tune/trial_runner.py in _process_events(self)
#     490
#     491     def _process_events(self):
# --> 492         trial = self.trial_executor.get_next_available_trial()  # blocking
#     493         with warn_if_slow("process_trial"):
#     494             self._process_trial(trial)
#
# ~/anaconda3/envs/flow/lib/python3.6/site-packages/ray/tune/ray_trial_executor.py in get_next_available_trial(self)
#     316         # See https://github.com/ray-project/ray/issues/4211 for details.
#     317         start = time.time()
# --> 318         [result_id], _ = ray.wait(shuffled_results)
#     319         wait_time = time.time() - start
#     320         if wait_time > NONTRIVIAL_WAIT_TIME_THRESHOLD_S:
#
# ~/anaconda3/envs/flow/lib/python3.6/site-packages/ray/worker.py in wait(object_ids, num_returns, timeout)
#    2370             timeout_milliseconds,
#    2371             False,
# -> 2372             worker.current_task_id,
#    2373         )
#    2374         return ready_ids, remaining_ids
#
# python/ray/_raylet.pyx in ray._raylet.RayletClient.wait()
#
# python/ray/_raylet.pyx in ray._raylet.check_status()
#
# ~/anaconda3/envs/flow/lib/python3.6/site-packages/ray/exceptions.py in __init__(self, client_exc)
#      84     """
#      85
# ---> 86     def __init__(self, client_exc):
#      87         self.client_exc = client_exc
#      88
#
# KeyboardInterrupt:

# %% [markdown]
# # /!\ Voir tutoriel 10 pour controle des feux
