# %% [markdown]
# # Train Vehicles Agents
#
#
# - crée un network à partir d'un fichier .osm et des trajectoires de véhiculess
# - ajoute un flux de voiture sur les routes
# - personnalise un Environnement pour le RL
# - integre l'environnement pour RLlib et execute la simulation

# %%
from flow.core.params import VehicleParams
from flow.core.params import NetParams, SumoCarFollowingParams
from flow.core.params import InitialConfig
from flow.core.params import EnvParams
from flow.core.params import SumoParams
from flow.controllers import RLController, IDMController
from flow.networks import Network
from flow.core.params import InFlows

# %% [markdown]
# ## Crée le network

# %% [markdown]
# Specifie les noms des routes du network dont les vehicules peuvent être s'insérer

# %%
EDGES_DISTRIBUTION = ["-100822066","4794817","4783299#0","155558218"]

# %% [markdown]
# créer la classe Network pour spécifier les itinéraires possibles

# %%
class IssyOSMNetwork(Network):

    def specify_routes(self, net_params):
        return {
            "-100822066": [ #N
                "-100822066",
                "-352962858#1",
                "-352962858#0",
                "-4786940#1",
                 "-4786940#0",
            ],
            
            "4794817" : [ #Loop
                "4794817",
                "4786972#0",
                "4786972#1",
                "4786972#2",
                "4786965#1",
                "4786965#2",
                "4786965#3",
                "4795729",
                "-352962858#1",
                "4795742#0",
                "4795742#1",
                "4786965#3",
                "4786965#4",
                "4786965#5",
            ],
            
            "4783299#0": [    #E
                "4783299#0",
                "4783299#1",
                "4783299#2",
                "4783299#3",
                "4783299#4",
                "4783299#5",
                "4783299#6",
                "4786940#0",
                "4786940#1",
                "352962858#0",
                "352962858#1",
                "100822066",
            ],
            
            "155558218": [
                "155558218",
                "4786940#1",
                "352962858#0",
                "352962858#1",
                "100822066",
            ],     
        }

# %% [markdown]
# ## Ajoute les flux de voiture

# %% [markdown]
# `IDMController` : The Intelligent Driver Model is a car-following model specifying vehicle dynamics by a differential equation for acceleration $\dot{v}$.
#
# `RLController` : a trainable autuonomous vehicle whose actions are dictated by an RL agent.

# %%
vehicles = VehicleParams()
vehicles.add("human",acceleration_controller=(IDMController, {}),num_vehicles=10)
vehicles.add("rl",acceleration_controller=(RLController, {}),num_vehicles=2)

# %% [markdown]
# - `vehs_per_hour`: nombre de vehicule par heure, uniformément espacés. Par exemple, comme il y a $60 \times 60 = 3600$ secondes dans une heure, le parametre $\frac{3600}{5}=720$ va faire rentrer des vehicules dans le network toutes les $5$ secondes.
#
# - `probability`: c'est la probabilité qu'un véhicule entre dans le network toutes les secondes. Par exemple, si on la fixe à $0.2$, alors chaque seconde de la simulation un véhicule aura $\frac{1}{5}$ chance d'entrer dans le network
#
# - `period`: C'est le temps en secondes entre 2 véhicules qui sont insérés. Par exemple, le fixer à $5$ ferait rentrer des véhicules dans le network toutes les $5$ secondes (ce qui équivaut à mettre `vehs_per_hour` à $720$).
#
# <font color='red'>
# $\rightarrow$ Exactement 1 seul de ces 3 paramètres doit être configurer !
# </font>

# %%
inflow = InFlows()

inflow.add(veh_type      = "human",
           edge          = "4794817",
           probability   = 0.3, 
           depart_speed  = 7,
           depart_lane   = "random")

inflow.add(veh_type      = "human",
           edge          = "4783299#0",
           probability   = 0.2,
           depart_speed  = 7,
           depart_lane   = "random")

inflow.add(veh_type       = "human",
           edge           = "-100822066",
           probability    = 0.25,
           depart_speed   = 7,
           depart_lane    = "random")

inflow.add(veh_type       = "rl",
           edge           = "-100822066",
           probability    = 0.05,
           depart_speed   = 7,
           depart_lane    = "random",
           color          = "blue")

inflow.add(veh_type       = "human",
           edge          = "155558218",
           probability   = 0.2,
           depart_speed  = 7,
           depart_lane   = "random")

# %% [markdown]
# ## Personnalise un Environnement pour le RL
#
# plus de méthodes sur : http://berkeleyflow.readthedocs.io/en/latest/

# %%
# import the base environment class
from flow.envs import Env
from gym.spaces.box import Box
from gym.spaces import Tuple
import numpy as np

# %% [markdown]
# ### definition de la classe environnement

# %%
class myEnv(Env):
    pass

# %% [markdown]
# ### fonction action_space
# 2 actions possibles pour chaque véhicule RL : +1 acceleration ou -1 acceleration

# %%
class myEnv(myEnv): # update my environment class

    @property
    def action_space(self):
        num_actions = self.initial_vehicles.num_rl_vehicles
        accel_ub = self.env_params.additional_params["max_accel"]
        accel_lb = - abs(self.env_params.additional_params["max_decel"])

        return Box(low=accel_lb, high=accel_ub, shape=(num_actions,))

# %% [markdown]
# ### observation_space
# 2 valeurs observé pour chaque véhicule: sa **position** et sa **vitesse**. En conséquence, nous avons besoin d'un espace d'observation qui est *deux fois plus grand que le nombre de véhicules* dans le network.

# %%
class myEnv(myEnv):  # update my environment class

    @property
    def observation_space(self):
        return Box(
            low=0,
            high=float("inf"),
            shape=(2*self.initial_vehicles.num_vehicles,))

# %% [markdown]
# ### apply_rl_actions
# `apply_rl_actions` : transforme les commandes de l'agent RL en actions réelles du simulateur.
#
# Pour notre exemple, l'agent RL peut spécifier que les accélérations des véhicules RL avec la fonction **apply_acceleration**

# %%
class myEnv(myEnv):  # update my environment class

    def _apply_rl_actions(self, rl_actions):
        # the names of all autonomous (RL) vehicles in the network
        rl_ids = self.k.vehicle.get_rl_ids()

        # use the base environment method to convert actions into accelerations for the rl vehicles
        self.k.vehicle.apply_acceleration(rl_ids, rl_actions)

# %% [markdown]
# ### get_state
#
# `get_state` : extrait des features de l'environnement et fournit ensuite des entrées à la stratégie fournie par l'agent RL.

# %%
class myEnv(myEnv):  # update my environment class

    def get_state(self, **kwargs):
        # the get_ids() method is used to get the names of all vehicles in the network
        ids = self.k.vehicle.get_ids()

        # we use the get_absolute_position method to get the positions of all vehicles
        pos = [self.k.vehicle.get_x_by_id(veh_id) for veh_id in ids]

        # we use the get_speed method to get the velocities of all vehicles
        vel = [self.k.vehicle.get_speed(veh_id) for veh_id in ids]

        # the speeds and positions are concatenated to produce the state
        return np.concatenate((pos, vel))

# %% [markdown]
# ### compute_reward
#
# `compute_reward` : renvoie la récompense associée à un état donné.
#
# Ici, la fonction de récompense est la **vitesse moyenne de tous les véhicules actuellement sur le réseau**.

# %%
class myEnv(myEnv):  # update my environment class

    def compute_reward(self, rl_actions, **kwargs):
        # the get_ids() method is used to get the names of all vehicles in the network
        ids = self.k.vehicle.get_ids()

        # we next get a list of the speeds of all vehicles in the network
        speeds = self.k.vehicle.get_speed(ids)

        # finally, we return the average of all these speeds as the reward
        return np.mean(speeds)

# %% [markdown]
# ## Lance une simulation avec Training RLlib
#
# Pour qu'un environnement puisse être entrainé, l'environnement doit être accessible via l'importation à partir de flow.envs.
#
#
# <font color='red'>
# Copier l'environnement créé dans un fichier .py et on importe l'environnement dans `flow.envs.__init__.py`.
# Mettre le chemin absolu du fichier .osm .
# </font>

# %%
import json
import ray
from ray.rllib.agents.registry import get_agent_class
from ray.tune import run_experiments
from ray.tune.registry import register_env

from flow.networks.ring import ADDITIONAL_NET_PARAMS
from flow.utils.registry import make_create_env
from flow.utils.rllib import FlowParamsEncoder
from flow.core.params import VehicleParams, SumoCarFollowingParams

#from flow.envs import AccelEnv as myEnv
#ADDITIONAL_ENV_PARAMS = {"target_velocity": 20,"sort_vehicles": False,"max_accel": 1,"max_decel": 1}
from myenv import myEnv as myEnv
ADDITIONAL_ENV_PARAMS = {"max_accel": 1, "max_decel": 1}

# %%
HORIZON = 200

# %%
# number of rollouts per training iteration
N_ROLLOUTS = 10
# number of parallel workers
N_CPUS = 2

# SUMO PARAM
sumo_params = SumoParams(sim_step=0.1, render=False, restart_instance=True)

# ENVIRONMENT PARAM
env_params = EnvParams(additional_params=ADDITIONAL_ENV_PARAMS, horizon=HORIZON)

# NETWORK PARAM
additional_net_params = ADDITIONAL_NET_PARAMS.copy()
path_file  = '/home/julien/projet_CIL4SYS/issy.osm'
net_params = NetParams(inflows=inflow, osm_path=path_file) 

# NETWORK
network = IssyOSMNetwork

# INITIAL CONFIG
initial_config = InitialConfig(edges_distribution=EDGES_DISTRIBUTION)


flow_params = dict( exp_tag   = "ISSY_RL_train", 
                    env_name  = myEnv,  
                    network   = IssyOSMNetwork,
                    simulator = 'traci', # simulator that is used by the experiment
                    sim       = sumo_params,
                    env       = env_params,
                    net       = net_params,
                    veh       = vehicles,
                    initial   = initial_config)

def setup_exps():
    """Return the relevant components of an RLlib experiment.

    Returns
    -------
    str
        name of the training algorithm
    str
        name of the gym environment to be trained
    dict
        training configuration parameters
    """
    alg_run   = "PPO"
    agent_cls = get_agent_class(alg_run)
    config    = agent_cls._default_config.copy()
    config["num_workers"]      = N_CPUS
    config["train_batch_size"] = HORIZON * N_ROLLOUTS
    config["gamma"]            = 0.999  # discount rate
    config["use_gae"]          = True
    config["lambda"]           = 0.97
    config["kl_target"]        = 0.02
    config["num_sgd_iter"]     = 10
    config['clip_actions']     = False  # FIXME(ev) temporary ray bug
    config["horizon"]          = HORIZON
    config["model"].update({"fcnet_hiddens": [3, 3]})
    
    # save the flow params for replay
    flow_json = json.dumps( flow_params, cls=FlowParamsEncoder, sort_keys=True, indent=4)
    config['env_config']['flow_params'] = flow_json
    config['env_config']['run'] = alg_run

    create_env, gym_name = make_create_env(params=flow_params, version=0)

    # Register as rllib env
    register_env(gym_name, create_env)
    
    return alg_run, gym_name, config


alg_run, gym_name, config = setup_exps()

ray.init(num_cpus=N_CPUS + 1)

trials = run_experiments({
    flow_params["exp_tag"]: {
        "run": alg_run,
        "env": gym_name,
        "config": {**config},
        "checkpoint_freq": 500,
        "checkpoint_at_end": True,
        "max_failures": 999,
        "stop": {"training_iteration": 5},
    }
})
# Out:
# 2020-03-26 10:28:56,306	INFO node.py:498 -- Process STDOUT and STDERR is being redirected to /tmp/ray/session_2020-03-26_10-28-56_306042_13427/logs.
# 2020-03-26 10:28:56,437	INFO services.py:409 -- Waiting for redis server at 127.0.0.1:24170 to respond...
# 2020-03-26 10:28:56,575	INFO services.py:409 -- Waiting for redis server at 127.0.0.1:63946 to respond...
# 2020-03-26 10:28:56,585	INFO services.py:809 -- Starting Redis shard with 2.09 GB max memory.
# 2020-03-26 10:28:56,657	INFO node.py:512 -- Process STDOUT and STDERR is being redirected to /tmp/ray/session_2020-03-26_10-28-56_306042_13427/logs.
# 2020-03-26 10:28:56,660	INFO services.py:1475 -- Starting the Plasma object store with 3.14 GB memory using /dev/shm.
# 2020-03-26 10:28:56,913	INFO trial_runner.py:176 -- Starting a new experiment.
# 2020-03-26 10:28:56,980	WARNING signature.py:108 -- The function with_updates has a **kwargs argument, which is currently not supported.
# 2020-03-26 10:28:57,027	ERROR log_sync.py:34 -- Log sync requires cluster to be setup with `ray up`.
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 0/3 CPUs, 0/0 GPUs
# Memory usage on this node: 2.7/10.5 GB
# 2020-03-26 10:28:57,190	WARNING util.py:145 -- The `start_trial` operation took 0.23308992385864258 seconds to complete, which may be a performance bottleneck.
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 3/3 CPUs, 0/0 GPUs
# Memory usage on this node: 2.7/10.5 GB
# Result logdir: /home/julien/ray_results/ISSY_RL_train
# Number of trials: 1 ({'RUNNING': 1})
# RUNNING trials:
#  - PPO_myEnv-v0_0:	RUNNING
#
# (pid=13464) 2020-03-26 10:29:03,752	WARNING ppo.py:143 -- FYI: By default, the value function will not share layers with the policy model ('vf_share_layers': False).
# (pid=13464) Warning: Discarding unknown compound 'cycleway.opposite' in type 'cycleway.opposite|highway.residential' (first occurence for edge '4786965#0').
# (pid=13464) Warning: Discarding unknown compound 'cycleway.opposite_track' in type 'cycleway.opposite_track|highway.residential' (first occurence for edge '4786972#0').
# (pid=13464) Warning: Discarding unknown compound 'cycleway.opposite' in type 'cycleway.opposite|highway.living_street' (first occurence for edge '4795758').
# (pid=13464) Warning: Discarding unknown compound 'cycleway.lane' in type 'cycleway.lane|highway.secondary' (first occurence for edge '100822066').
# (pid=13464) Warning: Removed a road without junctions: -21549451
# (pid=13464) Warning: Removed a road without junctions: 21549451
# (pid=13464) Warning: The traffic light '30624291' does not control any links; it will not be build.
# (pid=13464) Warning: Could not build program '0' for traffic light '30624291'
# (pid=13464) Warning: Minor green from edge '-352962858#0' to edge '4786972#0' exceeds 19.44m/s. Maybe a left-turn lane is missing.
# (pid=13464) Warning: Minor green from edge '352962858#0' to edge '4794820' exceeds 19.44m/s. Maybe a left-turn lane is missing.
# (pid=13464) Warning: Minor green from edge '-352962858#1' to edge '4795742#0' exceeds 19.44m/s. Maybe a left-turn lane is missing.
# (pid=13464) Success.
# (pid=13464) 2020-03-26 10:29:05,284	INFO rollout_worker.py:319 -- Creating policy evaluation worker 0 on CPU (please ignore any CUDA init errors)
# (pid=13464) 2020-03-26 10:29:05.285463: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2
# (pid=13464) 2020-03-26 10:29:05,648	INFO dynamic_tf_policy.py:324 -- Initializing loss function with dummy input:
# (pid=13464)
# (pid=13464) { 'action_prob': <tf.Tensor 'default_policy/action_prob:0' shape=(?,) dtype=float32>,
# (pid=13464)   'actions': <tf.Tensor 'default_policy/actions:0' shape=(?, 2) dtype=float32>,
# (pid=13464)   'advantages': <tf.Tensor 'default_policy/advantages:0' shape=(?,) dtype=float32>,
# (pid=13464)   'behaviour_logits': <tf.Tensor 'default_policy/behaviour_logits:0' shape=(?, 4) dtype=float32>,
# (pid=13464)   'dones': <tf.Tensor 'default_policy/dones:0' shape=(?,) dtype=bool>,
# (pid=13464)   'new_obs': <tf.Tensor 'default_policy/new_obs:0' shape=(?, 24) dtype=float32>,
# (pid=13464)   'obs': <tf.Tensor 'default_policy/observation:0' shape=(?, 24) dtype=float32>,
# (pid=13464)   'prev_actions': <tf.Tensor 'default_policy/action:0' shape=(?, 2) dtype=float32>,
# (pid=13464)   'prev_rewards': <tf.Tensor 'default_policy/prev_reward:0' shape=(?,) dtype=float32>,
# (pid=13464)   'rewards': <tf.Tensor 'default_policy/rewards:0' shape=(?,) dtype=float32>,
# (pid=13464)   'value_targets': <tf.Tensor 'default_policy/value_targets:0' shape=(?,) dtype=float32>,
# (pid=13464)   'vf_preds': <tf.Tensor 'default_policy/vf_preds:0' shape=(?,) dtype=float32>}
# (pid=13464)
# (pid=13464) /home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py:100: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
# (pid=13464)   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# (pid=13464) 2020-03-26 10:29:07,825	INFO rollout_worker.py:742 -- Built policy map: {'default_policy': <ray.rllib.policy.tf_policy_template.PPOTFPolicy object at 0x7f26ef0a37b8>}
# (pid=13464) 2020-03-26 10:29:07,825	INFO rollout_worker.py:743 -- Built preprocessor map: {'default_policy': <ray.rllib.models.preprocessors.NoPreprocessor object at 0x7f26ef0a3470>}
# (pid=13464) 2020-03-26 10:29:07,825	INFO rollout_worker.py:356 -- Built filter map: {'default_policy': <ray.rllib.utils.filter.NoFilter object at 0x7f26ef0a3320>}
# (pid=13464) 2020-03-26 10:29:07,915	INFO multi_gpu_optimizer.py:93 -- LocalMultiGPUOptimizer devices ['/cpu:0']
# (pid=13463) Warning: Discarding unknown compound 'cycleway.opposite' in type 'cycleway.opposite|highway.residential' (first occurence for edge '4786965#0').
# (pid=13463) Warning: Discarding unknown compound 'cycleway.opposite_track' in type 'cycleway.opposite_track|highway.residential' (first occurence for edge '4786972#0').
# (pid=13463) Warning: Discarding unknown compound 'cycleway.opposite' in type 'cycleway.opposite|highway.living_street' (first occurence for edge '4795758').
# (pid=13463) Warning: Discarding unknown compound 'cycleway.lane' in type 'cycleway.lane|highway.secondary' (first occurence for edge '100822066').
# (pid=13463) Warning: Removed a road without junctions: -21549451
# (pid=13463) Warning: Removed a road without junctions: 21549451
# (pid=13463) Warning: The traffic light '30624291' does not control any links; it will not be build.
# (pid=13463) Warning: Could not build program '0' for traffic light '30624291'
# (pid=13463) Warning: Minor green from edge '-352962858#0' to edge '4786972#0' exceeds 19.44m/s. Maybe a left-turn lane is missing.
# (pid=13463) Warning: Minor green from edge '352962858#0' to edge '4794820' exceeds 19.44m/s. Maybe a left-turn lane is missing.
# (pid=13463) Warning: Minor green from edge '-352962858#1' to edge '4795742#0' exceeds 19.44m/s. Maybe a left-turn lane is missing.
# (pid=13463) Success.
# (pid=13527) Warning: Discarding unknown compound 'cycleway.opposite' in type 'cycleway.opposite|highway.residential' (first occurence for edge '4786965#0').
# (pid=13527) Warning: Discarding unknown compound 'cycleway.opposite_track' in type 'cycleway.opposite_track|highway.residential' (first occurence for edge '4786972#0').
# (pid=13527) Warning: Discarding unknown compound 'cycleway.opposite' in type 'cycleway.opposite|highway.living_street' (first occurence for edge '4795758').
# (pid=13527) Warning: Discarding unknown compound 'cycleway.lane' in type 'cycleway.lane|highway.secondary' (first occurence for edge '100822066').
# (pid=13527) Warning: Removed a road without junctions: -21549451
# (pid=13527) Warning: Removed a road without junctions: 21549451
# (pid=13527) Warning: The traffic light '30624291' does not control any links; it will not be build.
# (pid=13527) Warning: Could not build program '0' for traffic light '30624291'
# (pid=13527) Warning: Minor green from edge '-352962858#0' to edge '4786972#0' exceeds 19.44m/s. Maybe a left-turn lane is missing.
# (pid=13527) Warning: Minor green from edge '352962858#0' to edge '4794820' exceeds 19.44m/s. Maybe a left-turn lane is missing.
# (pid=13527) Warning: Minor green from edge '-352962858#1' to edge '4795742#0' exceeds 19.44m/s. Maybe a left-turn lane is missing.
# (pid=13527) Success.
# (pid=13464) 2020-03-26 10:29:17,974	INFO trainable.py:105 -- _setup took 15.114 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# (pid=13464) 2020-03-26 10:29:17,974	WARNING util.py:47 -- Install gputil for GPU system monitoring.
# (pid=13463) 2020-03-26 10:29:17,995	INFO rollout_worker.py:319 -- Creating policy evaluation worker 1 on CPU (please ignore any CUDA init errors)
# (pid=13463) 2020-03-26 10:29:18.023319: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2
# (pid=13463) 2020-03-26 10:29:18,362	INFO dynamic_tf_policy.py:324 -- Initializing loss function with dummy input:
# (pid=13463)
# (pid=13463) { 'action_prob': <tf.Tensor 'default_policy/action_prob:0' shape=(?,) dtype=float32>,
# (pid=13463)   'actions': <tf.Tensor 'default_policy/actions:0' shape=(?, 2) dtype=float32>,
# (pid=13463)   'advantages': <tf.Tensor 'default_policy/advantages:0' shape=(?,) dtype=float32>,
# (pid=13463)   'behaviour_logits': <tf.Tensor 'default_policy/behaviour_logits:0' shape=(?, 4) dtype=float32>,
# (pid=13463)   'dones': <tf.Tensor 'default_policy/dones:0' shape=(?,) dtype=bool>,
# (pid=13463)   'new_obs': <tf.Tensor 'default_policy/new_obs:0' shape=(?, 24) dtype=float32>,
# (pid=13463)   'obs': <tf.Tensor 'default_policy/observation:0' shape=(?, 24) dtype=float32>,
# (pid=13463)   'prev_actions': <tf.Tensor 'default_policy/action:0' shape=(?, 2) dtype=float32>,
# (pid=13463)   'prev_rewards': <tf.Tensor 'default_policy/prev_reward:0' shape=(?,) dtype=float32>,
# (pid=13463)   'rewards': <tf.Tensor 'default_policy/rewards:0' shape=(?,) dtype=float32>,
# (pid=13463)   'value_targets': <tf.Tensor 'default_policy/value_targets:0' shape=(?,) dtype=float32>,
# (pid=13463)   'vf_preds': <tf.Tensor 'default_policy/vf_preds:0' shape=(?,) dtype=float32>}
# (pid=13463)
# (pid=13527) 2020-03-26 10:29:18,873	INFO rollout_worker.py:319 -- Creating policy evaluation worker 2 on CPU (please ignore any CUDA init errors)
# (pid=13527) 2020-03-26 10:29:18.994318: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2
# (pid=13463) /home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py:100: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
# (pid=13463)   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# (pid=13527) /home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py:100: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
# (pid=13527)   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# (pid=13463) 2020-03-26 10:29:22,305	INFO rollout_worker.py:451 -- Generating sample batch of size 200
# (pid=13463) Warning: Discarding unknown compound 'cycleway.opposite' in type 'cycleway.opposite|highway.residential' (first occurence for edge '4786965#0').
# (pid=13463) Warning: Discarding unknown compound 'cycleway.opposite_track' in type 'cycleway.opposite_track|highway.residential' (first occurence for edge '4786972#0').
# (pid=13463) Warning: Discarding unknown compound 'cycleway.opposite' in type 'cycleway.opposite|highway.living_street' (first occurence for edge '4795758').
# (pid=13463) Warning: Discarding unknown compound 'cycleway.lane' in type 'cycleway.lane|highway.secondary' (first occurence for edge '100822066').
# (pid=13463) Warning: Removed a road without junctions: -21549451
# (pid=13463) Warning: Removed a road without junctions: 21549451
# (pid=13463) Warning: The traffic light '30624291' does not control any links; it will not be build.
# (pid=13463) Warning: Could not build program '0' for traffic light '30624291'
# (pid=13463) Warning: Minor green from edge '-352962858#0' to edge '4786972#0' exceeds 19.44m/s. Maybe a left-turn lane is missing.
# (pid=13463) Warning: Minor green from edge '352962858#0' to edge '4794820' exceeds 19.44m/s. Maybe a left-turn lane is missing.
# (pid=13463) Warning: Minor green from edge '-352962858#1' to edge '4795742#0' exceeds 19.44m/s. Maybe a left-turn lane is missing.
# (pid=13463) Success.
# (pid=13527) Warning: Discarding unknown compound 'cycleway.opposite' in type 'cycleway.opposite|highway.residential' (first occurence for edge '4786965#0').
# (pid=13527) Warning: Discarding unknown compound 'cycleway.opposite_track' in type 'cycleway.opposite_track|highway.residential' (first occurence for edge '4786972#0').
# (pid=13527) Warning: Discarding unknown compound 'cycleway.opposite' in type 'cycleway.opposite|highway.living_street' (first occurence for edge '4795758').
# (pid=13527) Warning: Discarding unknown compound 'cycleway.lane' in type 'cycleway.lane|highway.secondary' (first occurence for edge '100822066').
# (pid=13527) Warning: Removed a road without junctions: -21549451
# (pid=13527) Warning: Removed a road without junctions: 21549451
# (pid=13527) Warning: The traffic light '30624291' does not control any links; it will not be build.
# (pid=13527) Warning: Could not build program '0' for traffic light '30624291'
# (pid=13527) Warning: Minor green from edge '-352962858#0' to edge '4786972#0' exceeds 19.44m/s. Maybe a left-turn lane is missing.
# (pid=13527) Warning: Minor green from edge '352962858#0' to edge '4794820' exceeds 19.44m/s. Maybe a left-turn lane is missing.
# (pid=13527) Warning: Minor green from edge '-352962858#1' to edge '4795742#0' exceeds 19.44m/s. Maybe a left-turn lane is missing.
# (pid=13527) Success.
# (pid=13463) 2020-03-26 10:29:23,973	INFO sampler.py:304 -- Raw obs from env: { 0: { 'agent0': np.ndarray((24,), dtype=float64, min=0.0, max=1850.367, mean=336.911)}}
# (pid=13463) 2020-03-26 10:29:23,974	INFO sampler.py:305 -- Info return from env: {0: {'agent0': None}}
# (pid=13463) 2020-03-26 10:29:23,974	INFO sampler.py:403 -- Preprocessed obs: np.ndarray((24,), dtype=float64, min=0.0, max=1850.367, mean=336.911)
# (pid=13463) 2020-03-26 10:29:23,975	INFO sampler.py:407 -- Filtered obs: np.ndarray((24,), dtype=float64, min=0.0, max=1850.367, mean=336.911)
# (pid=13463) 2020-03-26 10:29:23,979	INFO sampler.py:521 -- Inputs to compute_actions():
# (pid=13463)
# (pid=13463) { 'default_policy': [ { 'data': { 'agent_id': 'agent0',
# (pid=13463)                                   'env_id': 0,
# (pid=13463)                                   'info': None,
# (pid=13463)                                   'obs': np.ndarray((24,), dtype=float64, min=0.0, max=1850.367, mean=336.911),
# (pid=13463)                                   'prev_action': np.ndarray((2,), dtype=float32, min=0.0, max=0.0, mean=0.0),
# (pid=13463)                                   'prev_reward': 0.0,
# (pid=13463)                                   'rnn_state': []},
# (pid=13463)                         'type': 'PolicyEvalData'}]}
# (pid=13463)
# (pid=13463) 2020-03-26 10:29:23,979	INFO tf_run_builder.py:92 -- Executing TF run without tracing. To dump TF timeline traces to disk, set the TF_TIMELINE_DIR environment variable.
# (pid=13463) 2020-03-26 10:29:24,195	INFO sampler.py:548 -- Outputs of compute_actions():
# (pid=13463)
# (pid=13463) { 'default_policy': ( np.ndarray((1, 2), dtype=float32, min=-0.608, max=0.092, mean=-0.258),
# (pid=13463)                       [],
# (pid=13463)                       { 'action_prob': np.ndarray((1,), dtype=float32, min=0.131, max=0.131, mean=0.131),
# (pid=13463)                         'behaviour_logits': np.ndarray((1, 4), dtype=float32, min=-0.004, max=0.007, mean=0.001),
# (pid=13463)                         'vf_preds': np.ndarray((1,), dtype=float32, min=0.001, max=0.001, mean=0.001)})}
# (pid=13463)
# 2020-03-26 10:29:24,806	ERROR trial_runner.py:550 -- Error processing event.
# Traceback (most recent call last):
#   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/ray/tune/trial_runner.py", line 498, in _process_trial
#     result = self.trial_executor.fetch_result(trial)
#   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/ray/tune/ray_trial_executor.py", line 342, in fetch_result
#     result = ray.get(trial_future[0])
#   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/ray/worker.py", line 2247, in get
#     raise value
# ray.exceptions.RayTaskError: ray_PPO:train() (pid=13464, host=julien-Ubuntu)
#   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/ray/rllib/agents/trainer.py", line 369, in train
#     raise e
#   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/ray/rllib/agents/trainer.py", line 358, in train
#     result = Trainable.train(self)
#   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/ray/tune/trainable.py", line 171, in train
#     result = self._train()
#   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/ray/rllib/agents/trainer_template.py", line 126, in _train
#     fetches = self.optimizer.step()
#   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/ray/rllib/optimizers/multi_gpu_optimizer.py", line 140, in step
#     self.num_envs_per_worker, self.train_batch_size)
#   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/ray/rllib/optimizers/rollout.py", line 29, in collect_samples
#     next_sample = ray_get_and_free(fut_sample)
#   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/ray/rllib/utils/memory.py", line 33, in ray_get_and_free
#     result = ray.get(object_ids)
# ray.exceptions.RayTaskError: ray_RolloutWorker:sample() (pid=13463, host=julien-Ubuntu)
#   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/ray/rllib/utils/tf_run_builder.py", line 48, in get
#     self.feed_dict, os.environ.get("TF_TIMELINE_DIR"))
#   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/ray/rllib/utils/tf_run_builder.py", line 94, in run_timeline
#     fetches = sess.run(ops, feed_dict=feed_dict)
#   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 900, in run
#     run_metadata_ptr)
#   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 1111, in _run
#     str(subfeed_t.get_shape())))
# ValueError: Cannot feed value of shape (1, 26) for Tensor 'default_policy/observation:0', which has shape '(?, 24)'
#
# During handling of the above exception, another exception occurred:
#
# ray_RolloutWorker:sample() (pid=13463, host=julien-Ubuntu)
#   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/ray/rllib/evaluation/rollout_worker.py", line 453, in sample
#     batches = [self.input_reader.next()]
#   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/ray/rllib/evaluation/sampler.py", line 56, in next
#     batches = [self.get_data()]
#   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/ray/rllib/evaluation/sampler.py", line 97, in get_data
#     item = next(self.rollout_provider)
#   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/ray/rllib/evaluation/sampler.py", line 321, in _env_runner
#     active_episodes)
#   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/ray/rllib/evaluation/sampler.py", line 544, in _do_policy_eval
#     eval_results[k] = builder.get(v)
#   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/ray/rllib/utils/tf_run_builder.py", line 53, in get
#     self.fetches, self.feed_dict))
# ValueError: Error fetching: [<tf.Tensor 'default_policy/add:0' shape=(?, 2) dtype=float32>, {'action_prob': <tf.Tensor 'default_policy/Exp_1:0' shape=(?,) dtype=float32>, 'vf_preds': <tf.Tensor 'default_policy/value_function/Reshape:0' shape=(?,) dtype=float32>, 'behaviour_logits': <tf.Tensor 'default_policy/default_model_1/fc_net/fc_out/BiasAdd:0' shape=(?, 4) dtype=float32>}], feed_dict={<tf.Tensor 'default_policy/observation:0' shape=(?, 24) dtype=float32>: [array([ 1.23075098e+01,  1.23075098e+01, -1.00100000e+03, -1.00100000e+03,
#         3.24052095e+02,  3.77787212e+02,  4.31556516e+02,  7.34631516e+02,
#         7.34631516e+02,  1.75095915e+03,  1.79876203e+03,  1.85073889e+03,
#         3.04640000e+02,  3.74666865e+00,  3.74666865e+00,  6.49919943e+00,
#         6.49919943e+00,  3.73720760e+00,  3.73736398e+00,  3.76220214e+00,
#         3.76220214e+00,  3.76220214e+00,  3.69573948e+00,  9.56706060e-02,
#         2.73354283e-01,  7.00000000e+00])], <tf.Tensor 'default_policy/action:0' shape=(?, 2) dtype=float32>: [array([-0.73946   ,  0.80608004], dtype=float32)], <tf.Tensor 'default_policy/prev_reward:0' shape=(?,) dtype=float32>: [3.8705906558362293], <tf.Tensor 'default_policy/PlaceholderWithDefault:0' shape=() dtype=bool>: False}
#
#
# 2020-03-26 10:29:24,855	INFO trial_runner.py:587 -- Attempting to recover trial state from last checkpoint.
# 2020-03-26 10:29:24,869	WARNING signature.py:108 -- The function with_updates has a **kwargs argument, which is currently not supported.
# (pid=13464) 2020-03-26 10:29:24,799	INFO trainer.py:366 -- Worker crashed during call to train(). To attempt to continue training without the failed worker, set `'ignore_worker_failures': True`.
# (pid=13463) Warning: Choosing new speed factor 1.26 for vehicle 'flow_40.0' to match departure speed.
# (pid=13463) 2020-03-26 10:29:24,794	ERROR tf_run_builder.py:51 -- Error fetching: [<tf.Tensor 'default_policy/add:0' shape=(?, 2) dtype=float32>, {'action_prob': <tf.Tensor 'default_policy/Exp_1:0' shape=(?,) dtype=float32>, 'vf_preds': <tf.Tensor 'default_policy/value_function/Reshape:0' shape=(?,) dtype=float32>, 'behaviour_logits': <tf.Tensor 'default_policy/default_model_1/fc_net/fc_out/BiasAdd:0' shape=(?, 4) dtype=float32>}], feed_dict={<tf.Tensor 'default_policy/observation:0' shape=(?, 24) dtype=float32>: [array([ 1.23075098e+01,  1.23075098e+01, -1.00100000e+03, -1.00100000e+03,
# (pid=13463)         3.24052095e+02,  3.77787212e+02,  4.31556516e+02,  7.34631516e+02,
# (pid=13463)         7.34631516e+02,  1.75095915e+03,  1.79876203e+03,  1.85073889e+03,
# (pid=13463)         3.04640000e+02,  3.74666865e+00,  3.74666865e+00,  6.49919943e+00,
# (pid=13463)         6.49919943e+00,  3.73720760e+00,  3.73736398e+00,  3.76220214e+00,
# (pid=13463)         3.76220214e+00,  3.76220214e+00,  3.69573948e+00,  9.56706060e-02,
# (pid=13463)         2.73354283e-01,  7.00000000e+00])], <tf.Tensor 'default_policy/action:0' shape=(?, 2) dtype=float32>: [array([-0.73946   ,  0.80608004], dtype=float32)], <tf.Tensor 'default_policy/prev_reward:0' shape=(?,) dtype=float32>: [3.8705906558362293], <tf.Tensor 'default_policy/PlaceholderWithDefault:0' shape=() dtype=bool>: False}
# (pid=13463) Traceback (most recent call last):
# (pid=13463)   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/ray/rllib/utils/tf_run_builder.py", line 48, in get
# (pid=13463)     self.feed_dict, os.environ.get("TF_TIMELINE_DIR"))
# (pid=13463)   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/ray/rllib/utils/tf_run_builder.py", line 94, in run_timeline
# (pid=13463)     fetches = sess.run(ops, feed_dict=feed_dict)
# (pid=13463)   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 900, in run
# (pid=13463)     run_metadata_ptr)
# (pid=13463)   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 1111, in _run
# (pid=13463)     str(subfeed_t.get_shape())))
# (pid=13463) ValueError: Cannot feed value of shape (1, 26) for Tensor 'default_policy/observation:0', which has shape '(?, 24)'
# (pid=13463) Warning: Choosing new speed factor 1.26 for vehicle 'flow_40.1' to match departure speed.
# 2020-03-26 10:29:25,067	WARNING util.py:145 -- The `process_trial` operation took 0.26277995109558105 seconds to complete, which may be a performance bottleneck.
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 3/3 CPUs, 0/0 GPUs
# Memory usage on this node: 3.3/10.5 GB
# Result logdir: /home/julien/ray_results/ISSY_RL_train
# Number of trials: 1 ({'RUNNING': 1})
# RUNNING trials:
#  - PPO_myEnv-v0_0:	RUNNING, 1 failures: /home/julien/ray_results/ISSY_RL_train/PPO_myEnv-v0_0_2020-03-26_10-28-567gi9ep6x/error_2020-03-26_10-29-24.txt
#
# (pid=13527) 2020-03-26 10:29:26,052	ERROR tf_run_builder.py:51 -- Error fetching: [<tf.Tensor 'default_policy/add:0' shape=(?, 2) dtype=float32>, {'action_prob': <tf.Tensor 'default_policy/Exp_1:0' shape=(?,) dtype=float32>, 'vf_preds': <tf.Tensor 'default_policy/value_function/Reshape:0' shape=(?,) dtype=float32>, 'behaviour_logits': <tf.Tensor 'default_policy/default_model_1/fc_net/fc_out/BiasAdd:0' shape=(?, 4) dtype=float32>}], feed_dict={<tf.Tensor 'default_policy/observation:0' shape=(?, 24) dtype=float32>: [array([1.75743843e+01, 1.75743843e+01, 1.46052548e+02, 1.46052548e+02,
# (pid=13527)        3.29296643e+02, 3.83032171e+02, 4.36843151e+02, 7.39818151e+02,
# (pid=13527)        7.39818151e+02, 1.75610890e+03, 1.79976685e+03, 1.85159181e+03,
# (pid=13527)        7.22580000e+02, 4.93258206e+00, 4.93258206e+00, 8.64976065e+00,
# (pid=13527)        8.64976065e+00, 4.90508092e+00, 4.90564352e+00, 4.94979732e+00,
# (pid=13527)        4.94979732e+00, 4.94979732e+00, 4.76752124e+00, 4.41095370e-01,
# (pid=13527)        4.39685237e-01, 7.00000000e+00])], <tf.Tensor 'default_policy/action:0' shape=(?, 2) dtype=float32>: [array([1.4258535 , 0.70450807], dtype=float32)], <tf.Tensor 'default_policy/prev_reward:0' shape=(?,) dtype=float32>: [4.959469513239227], <tf.Tensor 'default_policy/PlaceholderWithDefault:0' shape=() dtype=bool>: False}
# (pid=13527) Traceback (most recent call last):
# (pid=13527)   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/ray/rllib/utils/tf_run_builder.py", line 48, in get
# (pid=13527)     self.feed_dict, os.environ.get("TF_TIMELINE_DIR"))
# (pid=13527)   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/ray/rllib/utils/tf_run_builder.py", line 94, in run_timeline
# (pid=13527)     fetches = sess.run(ops, feed_dict=feed_dict)
# (pid=13527)   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 900, in run
# (pid=13527)     run_metadata_ptr)
# (pid=13527)   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 1111, in _run
# (pid=13527)     str(subfeed_t.get_shape())))
# (pid=13527) ValueError: Cannot feed value of shape (1, 26) for Tensor 'default_policy/observation:0', which has shape '(?, 24)'
# (pid=13640) 2020-03-26 10:29:32,518	WARNING ppo.py:143 -- FYI: By default, the value function will not share layers with the policy model ('vf_share_layers': False).
# (pid=13640) Warning: Discarding unknown compound 'cycleway.opposite' in type 'cycleway.opposite|highway.residential' (first occurence for edge '4786965#0').
# (pid=13640) Warning: Discarding unknown compound 'cycleway.opposite_track' in type 'cycleway.opposite_track|highway.residential' (first occurence for edge '4786972#0').
# (pid=13640) Warning: Discarding unknown compound 'cycleway.opposite' in type 'cycleway.opposite|highway.living_street' (first occurence for edge '4795758').
# (pid=13640) Warning: Discarding unknown compound 'cycleway.lane' in type 'cycleway.lane|highway.secondary' (first occurence for edge '100822066').
# (pid=13640) Warning: Removed a road without junctions: -21549451
# (pid=13640) Warning: Removed a road without junctions: 21549451
# (pid=13640) Warning: The traffic light '30624291' does not control any links; it will not be build.
# (pid=13640) Warning: Could not build program '0' for traffic light '30624291'
# (pid=13640) Warning: Minor green from edge '-352962858#0' to edge '4786972#0' exceeds 19.44m/s. Maybe a left-turn lane is missing.
# (pid=13640) Warning: Minor green from edge '352962858#0' to edge '4794820' exceeds 19.44m/s. Maybe a left-turn lane is missing.
# (pid=13640) Warning: Minor green from edge '-352962858#1' to edge '4795742#0' exceeds 19.44m/s. Maybe a left-turn lane is missing.
# (pid=13640) Success.
# (pid=13640) 2020-03-26 10:29:34,168	INFO rollout_worker.py:319 -- Creating policy evaluation worker 0 on CPU (please ignore any CUDA init errors)
# (pid=13640) 2020-03-26 10:29:34.169046: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2
# (pid=13640) 2020-03-26 10:29:34,452	INFO dynamic_tf_policy.py:324 -- Initializing loss function with dummy input:
# (pid=13640)
# (pid=13640) { 'action_prob': <tf.Tensor 'default_policy/action_prob:0' shape=(?,) dtype=float32>,
# (pid=13640)   'actions': <tf.Tensor 'default_policy/actions:0' shape=(?, 2) dtype=float32>,
# (pid=13640)   'advantages': <tf.Tensor 'default_policy/advantages:0' shape=(?,) dtype=float32>,
# (pid=13640)   'behaviour_logits': <tf.Tensor 'default_policy/behaviour_logits:0' shape=(?, 4) dtype=float32>,
# (pid=13640)   'dones': <tf.Tensor 'default_policy/dones:0' shape=(?,) dtype=bool>,
# (pid=13640)   'new_obs': <tf.Tensor 'default_policy/new_obs:0' shape=(?, 24) dtype=float32>,
# (pid=13640)   'obs': <tf.Tensor 'default_policy/observation:0' shape=(?, 24) dtype=float32>,
# (pid=13640)   'prev_actions': <tf.Tensor 'default_policy/action:0' shape=(?, 2) dtype=float32>,
# (pid=13640)   'prev_rewards': <tf.Tensor 'default_policy/prev_reward:0' shape=(?,) dtype=float32>,
# (pid=13640)   'rewards': <tf.Tensor 'default_policy/rewards:0' shape=(?,) dtype=float32>,
# (pid=13640)   'value_targets': <tf.Tensor 'default_policy/value_targets:0' shape=(?,) dtype=float32>,
# (pid=13640)   'vf_preds': <tf.Tensor 'default_policy/vf_preds:0' shape=(?,) dtype=float32>}
# (pid=13640)
# (pid=13640) /home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py:100: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
# (pid=13640)   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# (pid=13640) 2020-03-26 10:29:37,091	INFO rollout_worker.py:742 -- Built policy map: {'default_policy': <ray.rllib.policy.tf_policy_template.PPOTFPolicy object at 0x7f5e957187f0>}
# (pid=13640) 2020-03-26 10:29:37,091	INFO rollout_worker.py:743 -- Built preprocessor map: {'default_policy': <ray.rllib.models.preprocessors.NoPreprocessor object at 0x7f5e957184a8>}
# (pid=13640) 2020-03-26 10:29:37,091	INFO rollout_worker.py:356 -- Built filter map: {'default_policy': <ray.rllib.utils.filter.NoFilter object at 0x7f5e95718358>}
# (pid=13640) 2020-03-26 10:29:37,229	INFO multi_gpu_optimizer.py:93 -- LocalMultiGPUOptimizer devices ['/cpu:0']
# (pid=13642) Warning: Discarding unknown compound 'cycleway.opposite' in type 'cycleway.opposite|highway.residential' (first occurence for edge '4786965#0').
# (pid=13642) Warning: Discarding unknown compound 'cycleway.opposite_track' in type 'cycleway.opposite_track|highway.residential' (first occurence for edge '4786972#0').
# (pid=13642) Warning: Discarding unknown compound 'cycleway.opposite' in type 'cycleway.opposite|highway.living_street' (first occurence for edge '4795758').
# (pid=13642) Warning: Discarding unknown compound 'cycleway.lane' in type 'cycleway.lane|highway.secondary' (first occurence for edge '100822066').
# (pid=13642) Warning: Removed a road without junctions: -21549451
# (pid=13642) Warning: Removed a road without junctions: 21549451
# (pid=13642) Warning: The traffic light '30624291' does not control any links; it will not be build.
# (pid=13642) Warning: Could not build program '0' for traffic light '30624291'
# (pid=13642) Warning: Minor green from edge '-352962858#0' to edge '4786972#0' exceeds 19.44m/s. Maybe a left-turn lane is missing.
# (pid=13642) Warning: Minor green from edge '352962858#0' to edge '4794820' exceeds 19.44m/s. Maybe a left-turn lane is missing.
# (pid=13642) Warning: Minor green from edge '-352962858#1' to edge '4795742#0' exceeds 19.44m/s. Maybe a left-turn lane is missing.
# (pid=13642) Success.
# (pid=13687) Warning: Discarding unknown compound 'cycleway.opposite' in type 'cycleway.opposite|highway.residential' (first occurence for edge '4786965#0').
# (pid=13687) Warning: Discarding unknown compound 'cycleway.opposite_track' in type 'cycleway.opposite_track|highway.residential' (first occurence for edge '4786972#0').
# (pid=13687) Warning: Discarding unknown compound 'cycleway.opposite' in type 'cycleway.opposite|highway.living_street' (first occurence for edge '4795758').
# (pid=13687) Warning: Discarding unknown compound 'cycleway.lane' in type 'cycleway.lane|highway.secondary' (first occurence for edge '100822066').
# (pid=13687) Warning: Removed a road without junctions: -21549451
# (pid=13687) Warning: Removed a road without junctions: 21549451
# (pid=13687) Warning: The traffic light '30624291' does not control any links; it will not be build.
# (pid=13687) Warning: Could not build program '0' for traffic light '30624291'
# (pid=13687) Warning: Minor green from edge '-352962858#0' to edge '4786972#0' exceeds 19.44m/s. Maybe a left-turn lane is missing.
# (pid=13687) Warning: Minor green from edge '352962858#0' to edge '4794820' exceeds 19.44m/s. Maybe a left-turn lane is missing.
# (pid=13687) Warning: Minor green from edge '-352962858#1' to edge '4795742#0' exceeds 19.44m/s. Maybe a left-turn lane is missing.
# (pid=13687) Success.
# (pid=13642) 2020-03-26 10:29:46,847	INFO rollout_worker.py:319 -- Creating policy evaluation worker 1 on CPU (please ignore any CUDA init errors)
# (pid=13642) 2020-03-26 10:29:46.874984: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2
# (pid=13642) 2020-03-26 10:29:47,578	INFO dynamic_tf_policy.py:324 -- Initializing loss function with dummy input:
# (pid=13642)
# (pid=13642) { 'action_prob': <tf.Tensor 'default_policy/action_prob:0' shape=(?,) dtype=float32>,
# (pid=13642)   'actions': <tf.Tensor 'default_policy/actions:0' shape=(?, 2) dtype=float32>,
# (pid=13642)   'advantages': <tf.Tensor 'default_policy/advantages:0' shape=(?,) dtype=float32>,
# (pid=13642)   'behaviour_logits': <tf.Tensor 'default_policy/behaviour_logits:0' shape=(?, 4) dtype=float32>,
# (pid=13642)   'dones': <tf.Tensor 'default_policy/dones:0' shape=(?,) dtype=bool>,
# (pid=13642)   'new_obs': <tf.Tensor 'default_policy/new_obs:0' shape=(?, 24) dtype=float32>,
# (pid=13642)   'obs': <tf.Tensor 'default_policy/observation:0' shape=(?, 24) dtype=float32>,
# (pid=13642)   'prev_actions': <tf.Tensor 'default_policy/action:0' shape=(?, 2) dtype=float32>,
# (pid=13642)   'prev_rewards': <tf.Tensor 'default_policy/prev_reward:0' shape=(?,) dtype=float32>,
# (pid=13642)   'rewards': <tf.Tensor 'default_policy/rewards:0' shape=(?,) dtype=float32>,
# (pid=13642)   'value_targets': <tf.Tensor 'default_policy/value_targets:0' shape=(?,) dtype=float32>,
# (pid=13642)   'vf_preds': <tf.Tensor 'default_policy/vf_preds:0' shape=(?,) dtype=float32>}
# (pid=13642)
# (pid=13687) 2020-03-26 10:29:47,600	INFO rollout_worker.py:319 -- Creating policy evaluation worker 2 on CPU (please ignore any CUDA init errors)
# (pid=13687) 2020-03-26 10:29:47.651046: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2
# (pid=13640) 2020-03-26 10:29:47,982	INFO trainable.py:105 -- _setup took 16.482 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# (pid=13640) 2020-03-26 10:29:47,983	WARNING util.py:47 -- Install gputil for GPU system monitoring.
# (pid=13642) /home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py:100: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
# (pid=13642)   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# (pid=13687) /home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py:100: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
# (pid=13687)   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# (pid=13642) 2020-03-26 10:29:50,666	INFO rollout_worker.py:451 -- Generating sample batch of size 200
# (pid=13642) Warning: Discarding unknown compound 'cycleway.opposite' in type 'cycleway.opposite|highway.residential' (first occurence for edge '4786965#0').
# (pid=13642) Warning: Discarding unknown compound 'cycleway.opposite_track' in type 'cycleway.opposite_track|highway.residential' (first occurence for edge '4786972#0').
# (pid=13642) Warning: Discarding unknown compound 'cycleway.opposite' in type 'cycleway.opposite|highway.living_street' (first occurence for edge '4795758').
# (pid=13642) Warning: Discarding unknown compound 'cycleway.lane' in type 'cycleway.lane|highway.secondary' (first occurence for edge '100822066').
# (pid=13642) Success.
# (pid=13642) Warning: Removed a road without junctions: -21549451
# (pid=13642) Warning: Removed a road without junctions: 21549451
# (pid=13642) Warning: The traffic light '30624291' does not control any links; it will not be build.
# (pid=13642) Warning: Could not build program '0' for traffic light '30624291'
# (pid=13642) Warning: Minor green from edge '-352962858#0' to edge '4786972#0' exceeds 19.44m/s. Maybe a left-turn lane is missing.
# (pid=13642) Warning: Minor green from edge '352962858#0' to edge '4794820' exceeds 19.44m/s. Maybe a left-turn lane is missing.
# (pid=13642) Warning: Minor green from edge '-352962858#1' to edge '4795742#0' exceeds 19.44m/s. Maybe a left-turn lane is missing.
# (pid=13687) Warning: Discarding unknown compound 'cycleway.opposite' in type 'cycleway.opposite|highway.residential' (first occurence for edge '4786965#0').
# (pid=13687) Warning: Discarding unknown compound 'cycleway.opposite_track' in type 'cycleway.opposite_track|highway.residential' (first occurence for edge '4786972#0').
# (pid=13687) Warning: Discarding unknown compound 'cycleway.opposite' in type 'cycleway.opposite|highway.living_street' (first occurence for edge '4795758').
# (pid=13687) Warning: Discarding unknown compound 'cycleway.lane' in type 'cycleway.lane|highway.secondary' (first occurence for edge '100822066').
# (pid=13687) Warning: Removed a road without junctions: -21549451
# (pid=13687) Warning: Removed a road without junctions: 21549451
# (pid=13687) Warning: The traffic light '30624291' does not control any links; it will not be build.
# (pid=13687) Warning: Could not build program '0' for traffic light '30624291'
# (pid=13687) Warning: Minor green from edge '-352962858#0' to edge '4786972#0' exceeds 19.44m/s. Maybe a left-turn lane is missing.
# (pid=13687) Warning: Minor green from edge '352962858#0' to edge '4794820' exceeds 19.44m/s. Maybe a left-turn lane is missing.
# (pid=13687) Warning: Minor green from edge '-352962858#1' to edge '4795742#0' exceeds 19.44m/s. Maybe a left-turn lane is missing.
# (pid=13687) Success.
# (pid=13642) 2020-03-26 10:29:52,216	INFO sampler.py:304 -- Raw obs from env: { 0: { 'agent0': np.ndarray((24,), dtype=float64, min=0.0, max=1850.367, mean=336.911)}}
# (pid=13642) 2020-03-26 10:29:52,217	INFO sampler.py:305 -- Info return from env: {0: {'agent0': None}}
# (pid=13642) 2020-03-26 10:29:52,217	INFO sampler.py:403 -- Preprocessed obs: np.ndarray((24,), dtype=float64, min=0.0, max=1850.367, mean=336.911)
# (pid=13642) 2020-03-26 10:29:52,217	INFO sampler.py:407 -- Filtered obs: np.ndarray((24,), dtype=float64, min=0.0, max=1850.367, mean=336.911)
# (pid=13642) 2020-03-26 10:29:52,219	INFO sampler.py:521 -- Inputs to compute_actions():
# (pid=13642)
# (pid=13642) { 'default_policy': [ { 'data': { 'agent_id': 'agent0',
# (pid=13642)                                   'env_id': 0,
# (pid=13642)                                   'info': None,
# (pid=13642)                                   'obs': np.ndarray((24,), dtype=float64, min=0.0, max=1850.367, mean=336.911),
# (pid=13642)                                   'prev_action': np.ndarray((2,), dtype=float32, min=0.0, max=0.0, mean=0.0),
# (pid=13642)                                   'prev_reward': 0.0,
# (pid=13642)                                   'rnn_state': []},
# (pid=13642)                         'type': 'PolicyEvalData'}]}
# (pid=13642)
# (pid=13642) 2020-03-26 10:29:52,219	INFO tf_run_builder.py:92 -- Executing TF run without tracing. To dump TF timeline traces to disk, set the TF_TIMELINE_DIR environment variable.
# (pid=13642) 2020-03-26 10:29:52,346	INFO sampler.py:548 -- Outputs of compute_actions():
# (pid=13642)
# (pid=13642) { 'default_policy': ( np.ndarray((1, 2), dtype=float32, min=1.072, max=2.212, mean=1.642),
# (pid=13642)                       [],
# (pid=13642)                       { 'action_prob': np.ndarray((1,), dtype=float32, min=0.008, max=0.008, mean=0.008),
# (pid=13642)                         'behaviour_logits': np.ndarray((1, 4), dtype=float32, min=-0.008, max=0.005, mean=-0.001),
# (pid=13642)                         'vf_preds': np.ndarray((1,), dtype=float32, min=0.004, max=0.004, mean=0.004)})}
# (pid=13642)
# 2020-03-26 10:29:53,040	ERROR trial_runner.py:550 -- Error processing event.
# Traceback (most recent call last):
#   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/ray/tune/trial_runner.py", line 498, in _process_trial
#     result = self.trial_executor.fetch_result(trial)
#   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/ray/tune/ray_trial_executor.py", line 342, in fetch_result
#     result = ray.get(trial_future[0])
#   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/ray/worker.py", line 2247, in get
#     raise value
# ray.exceptions.RayTaskError: ray_PPO:train() (pid=13640, host=julien-Ubuntu)
#   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/ray/rllib/agents/trainer.py", line 369, in train
#     raise e
#   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/ray/rllib/agents/trainer.py", line 358, in train
#     result = Trainable.train(self)
#   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/ray/tune/trainable.py", line 171, in train
#     result = self._train()
#   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/ray/rllib/agents/trainer_template.py", line 126, in _train
#     fetches = self.optimizer.step()
#   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/ray/rllib/optimizers/multi_gpu_optimizer.py", line 140, in step
#     self.num_envs_per_worker, self.train_batch_size)
#   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/ray/rllib/optimizers/rollout.py", line 29, in collect_samples
#     next_sample = ray_get_and_free(fut_sample)
#   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/ray/rllib/utils/memory.py", line 33, in ray_get_and_free
#     result = ray.get(object_ids)
# ray.exceptions.RayTaskError: ray_RolloutWorker:sample() (pid=13642, host=julien-Ubuntu)
#   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/ray/rllib/utils/tf_run_builder.py", line 48, in get
#     self.feed_dict, os.environ.get("TF_TIMELINE_DIR"))
#   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/ray/rllib/utils/tf_run_builder.py", line 94, in run_timeline
#     fetches = sess.run(ops, feed_dict=feed_dict)
#   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 900, in run
#     run_metadata_ptr)
#   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 1111, in _run
#     str(subfeed_t.get_shape())))
# ValueError: Cannot feed value of shape (1, 26) for Tensor 'default_policy/observation:0', which has shape '(?, 24)'
#
# During handling of the above exception, another exception occurred:
#
# ray_RolloutWorker:sample() (pid=13642, host=julien-Ubuntu)
#   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/ray/rllib/evaluation/rollout_worker.py", line 453, in sample
#     batches = [self.input_reader.next()]
#   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/ray/rllib/evaluation/sampler.py", line 56, in next
#     batches = [self.get_data()]
#   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/ray/rllib/evaluation/sampler.py", line 97, in get_data
#     item = next(self.rollout_provider)
#   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/ray/rllib/evaluation/sampler.py", line 321, in _env_runner
#     active_episodes)
#   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/ray/rllib/evaluation/sampler.py", line 544, in _do_policy_eval
#     eval_results[k] = builder.get(v)
#   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/ray/rllib/utils/tf_run_builder.py", line 53, in get
#     self.fetches, self.feed_dict))
# ValueError: Error fetching: [<tf.Tensor 'default_policy/add:0' shape=(?, 2) dtype=float32>, {'action_prob': <tf.Tensor 'default_policy/Exp_1:0' shape=(?,) dtype=float32>, 'vf_preds': <tf.Tensor 'default_policy/value_function/Reshape:0' shape=(?,) dtype=float32>, 'behaviour_logits': <tf.Tensor 'default_policy/default_model_1/fc_net/fc_out/BiasAdd:0' shape=(?, 4) dtype=float32>}], feed_dict={<tf.Tensor 'default_policy/observation:0' shape=(?, 24) dtype=float32>: [array([ 1.30864939e+01,  1.30864939e+01, -1.00100000e+03, -1.00100000e+03,
#         3.24828816e+02,  3.78563971e+02,  4.32338652e+02,  7.35413652e+02,
#         7.35413652e+02,  1.75173610e+03,  1.80019027e+03,  1.85070788e+03,
#         3.04640000e+02,  3.94433750e+00,  3.94433750e+00,  7.01919943e+00,
#         7.01919943e+00,  3.93238602e+00,  3.93258394e+00,  3.96017028e+00,
#         3.96017028e+00,  3.96017028e+00,  3.89231750e+00,  6.65609826e-01,
#         2.13640981e-13,  7.00000000e+00])], <tf.Tensor 'default_policy/action:0' shape=(?, 2) dtype=float32>: [array([-0.18600638, -1.8485091 ], dtype=float32)], <tf.Tensor 'default_policy/prev_reward:0' shape=(?,) dtype=float32>: [4.094652461955301], <tf.Tensor 'default_policy/PlaceholderWithDefault:0' shape=() dtype=bool>: False}
#
#
# 2020-03-26 10:29:53,056	INFO trial_runner.py:587 -- Attempting to recover trial state from last checkpoint.
# 2020-03-26 10:29:53,085	WARNING signature.py:108 -- The function with_updates has a **kwargs argument, which is currently not supported.
# 2020-03-26 10:29:53,185	WARNING util.py:145 -- The `process_trial` operation took 0.14627504348754883 seconds to complete, which may be a performance bottleneck.
# (pid=13640) 2020-03-26 10:29:53,034	INFO trainer.py:366 -- Worker crashed during call to train(). To attempt to continue training without the failed worker, set `'ignore_worker_failures': True`.
# (pid=13642) Warning: Choosing new speed factor 1.26 for vehicle 'flow_40.0' to match departure speed.
# (pid=13642) 2020-03-26 10:29:53,023	ERROR tf_run_builder.py:51 -- Error fetching: [<tf.Tensor 'default_policy/add:0' shape=(?, 2) dtype=float32>, {'action_prob': <tf.Tensor 'default_policy/Exp_1:0' shape=(?,) dtype=float32>, 'vf_preds': <tf.Tensor 'default_policy/value_function/Reshape:0' shape=(?,) dtype=float32>, 'behaviour_logits': <tf.Tensor 'default_policy/default_model_1/fc_net/fc_out/BiasAdd:0' shape=(?, 4) dtype=float32>}], feed_dict={<tf.Tensor 'default_policy/observation:0' shape=(?, 24) dtype=float32>: [array([ 1.30864939e+01,  1.30864939e+01, -1.00100000e+03, -1.00100000e+03,
# (pid=13642)         3.24828816e+02,  3.78563971e+02,  4.32338652e+02,  7.35413652e+02,
# (pid=13642)         7.35413652e+02,  1.75173610e+03,  1.80019027e+03,  1.85070788e+03,
# (pid=13642)         3.04640000e+02,  3.94433750e+00,  3.94433750e+00,  7.01919943e+00,
# (pid=13642)         7.01919943e+00,  3.93238602e+00,  3.93258394e+00,  3.96017028e+00,
# (pid=13642)         3.96017028e+00,  3.96017028e+00,  3.89231750e+00,  6.65609826e-01,
# (pid=13642)         2.13640981e-13,  7.00000000e+00])], <tf.Tensor 'default_policy/action:0' shape=(?, 2) dtype=float32>: [array([-0.18600638, -1.8485091 ], dtype=float32)], <tf.Tensor 'default_policy/prev_reward:0' shape=(?,) dtype=float32>: [4.094652461955301], <tf.Tensor 'default_policy/PlaceholderWithDefault:0' shape=() dtype=bool>: False}
# (pid=13642) Traceback (most recent call last):
# (pid=13642)   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/ray/rllib/utils/tf_run_builder.py", line 48, in get
# (pid=13642)     self.feed_dict, os.environ.get("TF_TIMELINE_DIR"))
# (pid=13642)   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/ray/rllib/utils/tf_run_builder.py", line 94, in run_timeline
# (pid=13642)     fetches = sess.run(ops, feed_dict=feed_dict)
# (pid=13642)   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 900, in run
# (pid=13642)     run_metadata_ptr)
# (pid=13642)   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 1111, in _run
# (pid=13642)     str(subfeed_t.get_shape())))
# (pid=13642) ValueError: Cannot feed value of shape (1, 26) for Tensor 'default_policy/observation:0', which has shape '(?, 24)'
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 3/3 CPUs, 0/0 GPUs
# Memory usage on this node: 3.4/10.5 GB
# Result logdir: /home/julien/ray_results/ISSY_RL_train
# Number of trials: 1 ({'RUNNING': 1})
# RUNNING trials:
#  - PPO_myEnv-v0_0:	RUNNING, 2 failures: /home/julien/ray_results/ISSY_RL_train/PPO_myEnv-v0_0_2020-03-26_10-28-567gi9ep6x/error_2020-03-26_10-29-53.txt
#
# (pid=13687) 2020-03-26 10:29:54,048	ERROR tf_run_builder.py:51 -- Error fetching: [<tf.Tensor 'default_policy/add:0' shape=(?, 2) dtype=float32>, {'action_prob': <tf.Tensor 'default_policy/Exp_1:0' shape=(?,) dtype=float32>, 'vf_preds': <tf.Tensor 'default_policy/value_function/Reshape:0' shape=(?,) dtype=float32>, 'behaviour_logits': <tf.Tensor 'default_policy/default_model_1/fc_net/fc_out/BiasAdd:0' shape=(?, 4) dtype=float32>}], feed_dict={<tf.Tensor 'default_policy/observation:0' shape=(?, 24) dtype=float32>: [array([1.75743843e+01, 1.75743843e+01, 1.46052548e+02, 1.46052548e+02,
# (pid=13687)        3.29264990e+02, 3.83018000e+02, 4.36843151e+02, 7.39818151e+02,
# (pid=13687)        7.39818151e+02, 1.75609075e+03, 1.79873316e+03, 1.85073720e+03,
# (pid=13687)        7.22580000e+02, 4.93258206e+00, 4.93258206e+00, 8.64976065e+00,
# (pid=13687)        8.64976065e+00, 4.75983425e+00, 4.82366359e+00, 4.94979732e+00,
# (pid=13687)        4.94979732e+00, 4.94979732e+00, 4.75187738e+00, 2.83595243e-02,
# (pid=13687)        3.12305417e-02, 7.00000000e+00])], <tf.Tensor 'default_policy/action:0' shape=(?, 2) dtype=float32>: [array([-0.8858877, -1.5784892], dtype=float32)], <tf.Tensor 'default_policy/prev_reward:0' shape=(?,) dtype=float32>: [4.877618666626078], <tf.Tensor 'default_policy/PlaceholderWithDefault:0' shape=() dtype=bool>: False}
# (pid=13687) Traceback (most recent call last):
# (pid=13687)   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/ray/rllib/utils/tf_run_builder.py", line 48, in get
# (pid=13687)     self.feed_dict, os.environ.get("TF_TIMELINE_DIR"))
# (pid=13687)   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/ray/rllib/utils/tf_run_builder.py", line 94, in run_timeline
# (pid=13687)     fetches = sess.run(ops, feed_dict=feed_dict)
# (pid=13687)   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 900, in run
# (pid=13687)     run_metadata_ptr)
# (pid=13687)   File "/home/julien/anaconda3/envs/flow/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 1111, in _run
# (pid=13687)     str(subfeed_t.get_shape())))
# (pid=13687) ValueError: Cannot feed value of shape (1, 26) for Tensor 'default_policy/observation:0', which has shape '(?, 24)'
# (pid=13798) 2020-03-26 10:29:59,356	WARNING ppo.py:143 -- FYI: By default, the value function will not share layers with the policy model ('vf_share_layers': False).
# (pid=13798) Warning: Discarding unknown compound 'cycleway.opposite' in type 'cycleway.opposite|highway.residential' (first occurence for edge '4786965#0').
# (pid=13798) Warning: Discarding unknown compound 'cycleway.opposite_track' in type 'cycleway.opposite_track|highway.residential' (first occurence for edge '4786972#0').
# (pid=13798) Warning: Discarding unknown compound 'cycleway.opposite' in type 'cycleway.opposite|highway.living_street' (first occurence for edge '4795758').
# (pid=13798) Warning: Discarding unknown compound 'cycleway.lane' in type 'cycleway.lane|highway.secondary' (first occurence for edge '100822066').
# (pid=13798) Success.
# (pid=13798) Warning: Removed a road without junctions: -21549451
# (pid=13798) Warning: Removed a road without junctions: 21549451
# (pid=13798) Warning: The traffic light '30624291' does not control any links; it will not be build.
# (pid=13798) Warning: Could not build program '0' for traffic light '30624291'
# (pid=13798) Warning: Minor green from edge '-352962858#0' to edge '4786972#0' exceeds 19.44m/s. Maybe a left-turn lane is missing.
# (pid=13798) Warning: Minor green from edge '352962858#0' to edge '4794820' exceeds 19.44m/s. Maybe a left-turn lane is missing.
# (pid=13798) Warning: Minor green from edge '-352962858#1' to edge '4795742#0' exceeds 19.44m/s. Maybe a left-turn lane is missing.
# 2020-03-26 10:30:00,373	ERROR worker.py:1616 -- print_logs: Error 111 connecting to 10.0.2.15:24170. Connection refused.
# 2020-03-26 10:30:00,375	ERROR import_thread.py:89 -- ImportThread: Error 111 connecting to 10.0.2.15:24170. Connection refused.
# 2020-03-26 10:30:00,376	ERROR worker.py:1716 -- listen_error_messages_raylet: Error 111 connecting to 10.0.2.15:24170. Connection refused.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-6974486e1f81> in <module>
#      83         "checkpoint_at_end": True,
#      84         "max_failures": 999,
# ---> 85         "stop": {"training_iteration": 5},
#      86     }
#      87 })
#
# ~/anaconda3/envs/flow/lib/python3.6/site-packages/ray/tune/tune.py in run_experiments(experiments, search_alg, scheduler, with_server, server_port, verbose, resume, queue_trials, reuse_actors, trial_executor, raise_on_failed_trial)
#     322             trial_executor=trial_executor,
#     323             raise_on_failed_trial=raise_on_failed_trial,
# --> 324             return_trials=True)
#     325     return trials
#
# ~/anaconda3/envs/flow/lib/python3.6/site-packages/ray/tune/tune.py in run(run_or_experiment, name, stop, config, resources_per_trial, num_samples, local_dir, upload_dir, trial_name_creator, loggers, sync_to_cloud, sync_to_driver, checkpoint_freq, checkpoint_at_end, keep_checkpoints_num, checkpoint_score_attr, global_checkpoint_period, export_formats, max_failures, restore, search_alg, scheduler, with_server, server_port, verbose, resume, queue_trials, reuse_actors, trial_executor, raise_on_failed_trial, return_trials, ray_auto_init, sync_function)
#     242     last_debug = 0
#     243     while not runner.is_finished():
# --> 244         runner.step()
#     245         if time.time() - last_debug > DEBUG_PRINT_INTERVAL:
#     246             if verbose:
#
# ~/anaconda3/envs/flow/lib/python3.6/site-packages/ray/tune/trial_runner.py in step(self)
#     326                 self.trial_executor.start_trial(next_trial)
#     327         elif self.trial_executor.get_running_trials():
# --> 328             self._process_events()  # blocking
#     329         else:
#     330             for trial in self._trials:
#
# ~/anaconda3/envs/flow/lib/python3.6/site-packages/ray/tune/trial_runner.py in _process_events(self)
#     490
#     491     def _process_events(self):
# --> 492         trial = self.trial_executor.get_next_available_trial()  # blocking
#     493         with warn_if_slow("process_trial"):
#     494             self._process_trial(trial)
#
# ~/anaconda3/envs/flow/lib/python3.6/site-packages/ray/tune/ray_trial_executor.py in get_next_available_trial(self)
#     316         # See https://github.com/ray-project/ray/issues/4211 for details.
#     317         start = time.time()
# --> 318         [result_id], _ = ray.wait(shuffled_results)
#     319         wait_time = time.time() - start
#     320         if wait_time > NONTRIVIAL_WAIT_TIME_THRESHOLD_S:
#
# ~/anaconda3/envs/flow/lib/python3.6/site-packages/ray/worker.py in wait(object_ids, num_returns, timeout)
#    2370             timeout_milliseconds,
#    2371             False,
# -> 2372             worker.current_task_id,
#    2373         )
#    2374         return ready_ids, remaining_ids
#
# python/ray/_raylet.pyx in ray._raylet.RayletClient.wait()
#
# python/ray/_raylet.pyx in ray._raylet.check_status()
#
# ~/anaconda3/envs/flow/lib/python3.6/site-packages/ray/exceptions.py in __init__(self, client_exc)
#      84     """
#      85
# ---> 86     def __init__(self, client_exc):
#      87         self.client_exc = client_exc
#      88
#
# KeyboardInterrupt:
